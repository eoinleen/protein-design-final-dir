# %% [markdown]
# <a href="https://colab.research.google.com/github/eoinleen/protein-design-final-dir/blob/main/cp_RFdiffusion_pathway_str_analysis_tool_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Super Easy Protein Analysis Tool
===============================

What Does This Thing Do?
-----------------------
Takes your PDB files and your AlphaFold2 (AF2) scores and:
1. Measures the buried surface area, hydrogen bonds, hydrophobic contacts, and salt bridges of AF2 outputs from FRdiffusion->ProteinMPNN -> AF2 pipeline
2. Makes some nice graphs comparing your results
3. Saves everything in easy-to-use files

REALLY Simple Instructions:
---------------------------------------------------------------
1. Put these files in ONE folder:
   - This code (saved as something.py)
   - Your PDB files (must end in .pdb)
   - Your AF2 scores (must be called 'af2_scores.csv')

2. Change ONE Line in the Code:
   Find this line near the bottom:
   pdb_directory = '/content/drive/MyDrive/PDB-files/all_pdb_2MBO-12'

   Change it to where your files are, like:
   pdb_directory = '/content/drive/MyDrive/YOUR_FOLDER_NAME'

3. Run It:
   - Just click the play button
   - That's literally it

What You'll Get:
--------------
1. CSV files with all your numbers:
   - structure_analysis.csv: Measured parametres fron this macro
   - combined_analysis.csv: Everything combined with AF2 scores

2. Three pretty graphs showing:
   - How many hydrogen bonds vs. ipTM scores
   - How many hydrophobic contacts vs. ipTM scores
   - How much buried surface area vs. ipTM scores
   Each graph will highlight the top 15 designs!

Requirements:
-----------
1. Your PDB Files:
   - Must be named like: design5_n18.pdb
     (where 5 is the design number and 18 is the variant)
   - Must have two chains that interact

2. Your AF2 Scores File: (Called mpnn_results.csv in the outputs directory from the RFdiffusion colabsheet)
   - Must be named: af2_scores.csv
   - Must have columns: design, n, i_ptm
   - Other columns are fine too!

Common Problems:
--------------
If it says:
- "Drive not mounted": Click the link it shows you
- "No such directory": Check your folder path for typos
- "Error processing [filename]": That PDB file might be broken
- "Can't find output": Look in the same folder as your PDB files

Need More Help?
-------------
Look for these messages when it runs:
- "Processing X PDB files..." (it's working!)
- "Saved results to..." (shows where to find your files)
- Any error messages will tell you what went wrong

Written by: Claude (Anthropic)
Original code from: Claude & Windows Co-pilot, Dr Eoin Leen, University of Leeds
Version: 3.1 (2025)
"""

# Install required packages
# !pip install -q biopython pandas freesasa numpy matplotlib seaborn

# Import required libraries
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
from pathlib import Path
from typing import Dict, List, Optional, Tuple, Any
from Bio import PDB
from Bio.PDB.PDBIO import PDBIO
from Bio.PDB.Polypeptide import is_aa
from Bio.PDB.Structure import Structure
import freesasa
import numpy as np
from google.colab import drive

class StructureValidationError(Exception):
    pass

def validate_pdb_file(file_path: str) -> bool:
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"PDB file not found: {file_path}")

    try:
        with open(file_path, 'r') as f:
            first_line = f.readline()
            if not any(marker in first_line for marker in ['HEADER', 'ATOM', 'MODEL']):
                raise StructureValidationError(f"File does not appear to be a valid PDB: {file_path}")
    except UnicodeDecodeError:
        raise StructureValidationError(f"File is not a valid text file: {file_path}")

    return True

def safe_structure_load(parser: PDB.PDBParser, file_path: str) -> Optional[Structure]:
    try:
        validate_pdb_file(file_path)
        structure = parser.get_structure('protein', file_path)
        models = list(structure.get_models())
        if not models:
            raise StructureValidationError("Structure contains no models")
        chains = list(models[0].get_chains())
        if not chains:
            raise StructureValidationError("Structure contains no chains")
        return structure
    except Exception as e:
        print(f"Error loading structure {file_path}: {str(e)}")
        return None

def calculate_buried_surface_area(pdb_file: str) -> Tuple[Optional[float], Optional[Dict[str, float]]]:
    parser = PDB.PDBParser(QUIET=True)
    structure = safe_structure_load(parser, pdb_file)
    if not structure:
        return None, None
    try:
        chains = list(structure.get_chains())
        if len(chains) < 2:
            print(f"Warning: {pdb_file} has fewer than 2 chains, cannot calculate BSA")
            return None, None
        structure_atoms = [atom for atom in structure.get_atoms()]
        if not structure_atoms:
            print(f"Warning: {pdb_file} has no atoms")
            return None, None
        combined_structure = freesasa.Structure(pdb_file)
        result = freesasa.calc(combined_structure)
        total_area = result.totalArea()
        chain_areas: Dict[str, float] = {}
        io = PDBIO()
        temp_files: List[str] = []
        try:
            for chain in chains:
                new_structure = PDB.Structure.Structure('temp')
                new_model = PDB.Model.Model(0)
                new_structure.add(new_model)
                new_chain = chain.copy()
                new_model.add(new_chain)
                temp_file = f"temp_chain_{chain.id}.pdb"
                temp_files.append(temp_file)
                io.set_structure(new_structure)
                io.save(temp_file)
                chain_structure = freesasa.Structure(temp_file)
                chain_result = freesasa.calc(chain_structure)
                chain_areas[chain.id] = chain_result.totalArea()
        finally:
            for temp_file in temp_files:
                try:
                    if os.path.exists(temp_file):
                        os.remove(temp_file)
                except Exception as e:
                    print(f"Warning: Failed to remove temporary file {temp_file}: {str(e)}")
        total_individual_area = sum(chain_areas.values())
        buried_surface_area = abs(total_individual_area - total_area) / 2
        return buried_surface_area, chain_areas
    except Exception as e:
        print(f"Error calculating buried surface area for {pdb_file}: {str(e)}")
        return None, None

def calculate_hydrogen_bonds(structure: Structure) -> int:
    try:
        h_bonds = 0
        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id >= chain2.id:
                    continue
                for res1 in chain1.get_residues():
                    if not is_aa(res1):
                        continue
                    for res2 in chain2.get_residues():
                        if not is_aa(res2):
                            continue
                        try:
                            if 'O' in res1 and 'N' in res2:
                                distance = res1['O'] - res2['N']
                                if distance < 3.5:
                                    h_bonds += 1
                        except KeyError:
                            continue
        return h_bonds
    except Exception as e:
        print(f"Error calculating hydrogen bonds: {str(e)}")
        return 0

def calculate_hydrophobic_contacts(structure: Structure) -> int:
    try:
        hydrophobic_residues = {'ALA', 'VAL', 'LEU', 'ILE', 'MET', 'PHE', 'TRP', 'PRO'}
        contacts = 0
        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id >= chain2.id:
                    continue
                for res1 in chain1.get_residues():
                    if not is_aa(res1) or res1.get_resname() not in hydrophobic_residues:
                        continue
                    for res2 in chain2.get_residues():
                        if not is_aa(res2) or res2.get_resname() not in hydrophobic_residues:
                            continue
                        try:
                            min_distance = float('inf')
                            for atom1 in res1.get_atoms():
                                for atom2 in res2.get_atoms():
                                    distance = atom1 - atom2
                                    min_distance = min(min_distance, distance)
                            if min_distance < 5.0:
                                contacts += 1
                        except Exception:
                            continue
        return contacts
    except Exception as e:
        print(f"Error calculating hydrophobic contacts: {str(e)}")
        return 0

def calculate_salt_bridges(structure: Structure) -> int:
    try:
        acidic = {'ASP', 'GLU'}
        basic = {'LYS', 'ARG', 'HIS'}
        salt_bridges = 0
        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id >= chain2.id:
                    continue
                for res1 in chain1.get_residues():
                    if not is_aa(res1):
                        continue
                    res1_name = res1.get_resname()
                    for res2 in chain2.get_residues():
                        if not is_aa(res2):
                            continue
                        res2_name = res2.get_resname()
                        if (res1_name in acidic and res2_name in basic) or \
                           (res1_name in basic and res2_name in acidic):
                            try:
                                min_distance = float('inf')
                                for atom1 in res1.get_atoms():
                                    for atom2 in res2.get_atoms():
                                        distance = atom1 - atom2
                                        min_distance = min(min_distance, distance)
                                if min_distance < 4.0:
                                    salt_bridges += 1
                            except Exception:
                                continue
        return salt_bridges
    except Exception as e:
        print(f"Error calculating salt bridges: {str(e)}")
        return 0

def save_results_as_df(results: List[Dict[str, Any]], pdb_directory: str, output_file: str = "structure_analysis.csv") -> pd.DataFrame:
    analysis_data = []
    for result in results:
        filename = result['file_name'].replace('.pdb', '')
        try:
            design_num = int(filename.split('design')[1].split('_')[0])
            variant_num = int(filename.split('_n')[1])
            analysis_data.append({
                'design': design_num,
                'n': variant_num,
                'buried_surface_area': result['buried_surface_area'] if result['buried_surface_area'] else 0,
                'hydrogen_bonds': result['hydrogen_bonds'],
                'hydrophobic_contacts': result['hydrophobic_contacts'],
                'salt_bridges': result['salt_bridges']
            })
        except Exception as e:
            print(f"Error parsing filename {filename}: {str(e)}")
            continue
    df = pd.DataFrame(analysis_data)
    df = df.sort_values(['design', 'n']).reset_index(drop=True)
    full_output_path = os.path.join(pdb_directory, output_file)
    df.to_csv(full_output_path, index=False)
    print(f"Saved structure analysis results to {full_output_path}")
    try:
        files.download(full_output_path)
        print(f"Downloaded {output_file} to your computer")
    except Exception as e:
        print(f"Note: Could not auto-download file: {str(e)}")
    return df

def merge_with_af2_scores(structure_df: pd.DataFrame, af2_scores_file: str) -> pd.DataFrame:
    af2_df = pd.read_csv(af2_scores_file)
    merged_df = pd.merge(
        af2_df,
        structure_df,
        on=['design', 'n'],
        how='left'
    )
    merged_df = merged_df.sort_values(['design', 'n']).reset_index(drop=True)
    return merged_df

def make_scatter_plots(df: pd.DataFrame, pdb_directory: str):
    metrics = {
        'hydrogen_bonds': 'Number of Hydrogen Bonds',
        'hydrophobic_contacts': 'Number of Hydrophobic Contacts',
        'buried_surface_area': 'Buried Surface Area (Å²)'
    }
    for metric, ylabel in metrics.items():
        plt.figure(figsize=(10, 6))
        plt.scatter(df[metric], df['i_ptm'], alpha=0.5)
        plt.xlabel(ylabel)
        plt.ylabel('ipTM Score')
        plt.title(f'ipTM Score vs {ylabel}')
        top_15 = df.nlargest(15, 'i_ptm')
        for _, row in top_15.iterrows():
            plt.annotate(f'({int(row["design"])},{int(row["n"])})',
                       (row[metric], row['i_ptm']))
        plt.grid(True, alpha=0.3)
        plt.savefig(os.path.join(pdb_directory, f'plot_{metric}.png'))
        plt.close()

def process_multiple_pdb_files(pdb_directory: str, af2_scores_file: str = None) -> pd.DataFrame:
    if not os.path.exists(pdb_directory):
        raise FileNotFoundError(f"Directory not found: {pdb_directory}")
    results = []
    parser = PDB.PDBParser(QUIET=True)
    pdb_files = [f for f in os.listdir(pdb_directory) if f.endswith('.pdb')]
    if not pdb_files:
        print(f"Warning: No PDB files found in {pdb_directory}")
        return pd.DataFrame()
    print(f"Processing {len(pdb_files)} PDB files...")
    for file_name in pdb_files:
        pdb_file = os.path.join(pdb_directory, file_name)
        print(f"Processing {file_name}...")
        try:
            structure = safe_structure_load(parser, pdb_file)
            if not structure:
                continue
            buried_surface_area, chain_areas = calculate_buried_surface_area(pdb_file)
            h_bonds = calculate_hydrogen_bonds(structure)
            hydrophobic = calculate_hydrophobic_contacts(structure)
            salt_bridges = calculate_salt_bridges(structure)
            results.append({
                'file_name': file_name,
                'buried_surface_area': buried_surface_area,
                'hydrogen_bonds': h_bonds,
                'hydrophobic_contacts': hydrophobic,
                'salt_bridges': salt_bridges,
                'chain_areas': chain_areas
            })
        except Exception as e:
            print(f"Error processing {file_name}: {str(e)}")
            continue
    structure_df = save_results_as_df(results, pdb_directory, "structure_analysis.csv")
    if af2_scores_file and os.path.exists(af2_scores_file):
        print(f"Merging with AF2 scores from {af2_scores_file}")
        final_df = merge_with_af2_scores(structure_df, af2_scores_file)
        combined_file = os.path.join(pdb_directory, "combined_analysis.csv")
        final_df.to_csv(combined_file, index=False)
        print(f"Saved combined results to {combined_file}")
        print("\nGenerating plots...")
        make_scatter_plots(final_df, pdb_directory)
        try:
            files.download(combined_file)
            print(f"Downloaded combined_analysis.csv to your computer")
            for metric in ['hydrogen_bonds', 'hydrophobic_contacts', 'buried_surface_area']:
                plot_file = f'plot_{metric}.png'
                files.download(os.path.join(pdb_directory, plot_file))
                print(f"Downloaded {plot_file}")
        except Exception as e:
            print(f"Note: Could not auto-download files: {str(e)}")
        return final_df
    return structure_df

try:
    try:
        drive.mount('/content/drive')
    except Exception as e:
        print(f"Warning: Drive mounting failed: {str(e)}")
        print("Proceeding with local filesystem access only")

    pdb_directory = '/content/drive/MyDrive/PDB-files/all_pdb_2MBO-12'
    af2_scores_path = os.path.join(pdb_directory, 'af2_scores.csv')
    if not os.path.exists(af2_scores_path):
        af2_scores_path = None
        print("No AF2 scores file found - will generate structure analysis only")

    print("Starting analysis...")
    print(f"Processing PDB files from: {pdb_directory}")
    print(f"Results will be saved to the same directory")

    results_df = process_multiple_pdb_files(pdb_directory, af2_scores_path)

except Exception as e:
    print(f"Fatal error: {str(e)}")
    sys.exit(1)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.1/270.1 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 47.4 MB/s eta 0:00:00
#   Building wheel for freesasa (setup.py) ... done
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Starting analysis...
# Processing PDB files from: /content/drive/MyDrive/PDB-files/all_pdb_2MBO-12
# Results will be saved to the same directory
# Processing 2048 PDB files...
# Processing design18_n48.pdb...
# Processing design10_n46.pdb...
# Processing design25_n63.pdb...
# Processing design3_n41.pdb...
# Processing design9_n41.pdb...
# Processing design5_n7.pdb...
# Processing design0_n14.pdb...
# Processing design14_n8.pdb...
# Processing design17_n55.pdb...
# Processing design29_n7.pdb...
# Processing design7_n55.pdb...
# Processing design0_n48.pdb...
# Processing design18_n43.pdb...
# Processing design30_n53.pdb...
# Processing design30_n40.pdb...
# Processing design21_n31.pdb...
# Processing design17_n62.pdb...
# Processing design30_n4.pdb...
# Processing design5_n28.pdb...
# Processing design27_n17.pdb...
# Processing design18_n14.pdb...
# Processing design19_n32.pdb...
# Processing design11_n30.pdb...
# Processing design9_n17.pdb...
# Processing design18_n54.pdb...
# Processing design12_n24.pdb...
# Processing design13_n54.pdb...
# Processing design5_n8.pdb...
# Processing design21_n26.pdb...
# Processing design29_n63.pdb...
# Processing design2_n49.pdb...
# Processing design2_n6.pdb...
# Processing design10_n52.pdb...
# Processing design11_n56.pdb...
# Processing design10_n17.pdb...
# Processing design29_n38.pdb...
# Processing design15_n21.pdb...
# Processing design12_n7.pdb...
# Processing design30_n17.pdb...
# Processing design14_n3.pdb...
# Processing design25_n38.pdb...
# Processing design19_n18.pdb...
# Processing design11_n28.pdb...
# Processing design4_n58.pdb...
# Processing design21_n36.pdb...
# Processing design26_n23.pdb...
# Processing design17_n57.pdb...
# Processing design2_n30.pdb...
# Processing design0_n61.pdb...
# Processing design30_n20.pdb...
# Processing design26_n7.pdb...
# Processing design28_n39.pdb...
# Processing design18_n23.pdb...
# Processing design12_n48.pdb...
# Processing design12_n3.pdb...
# Processing design26_n26.pdb...
# Processing design12_n18.pdb...
# Processing design3_n52.pdb...
# Processing design29_n17.pdb...
# Processing design15_n15.pdb...
# Processing design18_n40.pdb...
# Processing design30_n2.pdb...
# Processing design21_n44.pdb...
# Processing design18_n49.pdb...
# Processing design20_n35.pdb...
# Processing design10_n23.pdb...
# Processing design21_n28.pdb...
# Processing design5_n53.pdb...
# Processing design31_n61.pdb...
# Processing design5_n14.pdb...
# Processing design8_n6.pdb...
# Processing design15_n56.pdb...
# Processing design16_n53.pdb...
# Processing design22_n14.pdb...
# Processing design4_n19.pdb...
# Processing design11_n25.pdb...
# Processing design24_n12.pdb...
# Processing design2_n10.pdb...
# Processing design30_n49.pdb...
# Processing design25_n18.pdb...
# Processing design22_n43.pdb...
# Processing design23_n47.pdb...
# Processing design18_n47.pdb...
# Processing design21_n62.pdb...
# Processing design8_n18.pdb...
# Processing design20_n9.pdb...
# Processing design30_n5.pdb...
# Processing design22_n15.pdb...
# Processing design9_n9.pdb...
# Processing design10_n9.pdb...
# Processing design5_n50.pdb...
# Processing design27_n41.pdb...
# Processing design3_n34.pdb...
# Processing design24_n28.pdb...
# Processing design21_n29.pdb...
# Processing design3_n6.pdb...
# Processing design13_n5.pdb...
# Processing design20_n38.pdb...
# Processing design17_n24.pdb...
# Processing design27_n59.pdb...
# Processing design17_n18.pdb...
# Processing design4_n34.pdb...
# Processing design3_n44.pdb...
# Processing design1_n38.pdb...
# Processing design19_n40.pdb...
# Processing design12_n42.pdb...
# Processing design8_n31.pdb...
# Processing design6_n23.pdb...
# Processing design24_n38.pdb...
# Processing design22_n24.pdb...
# Processing design28_n40.pdb...
# Processing design1_n3.pdb...
# Processing design4_n30.pdb...
# Processing design30_n10.pdb...
# Processing design9_n7.pdb...
# Processing design5_n43.pdb...
# Processing design20_n41.pdb...
# Processing design14_n6.pdb...
# Processing design5_n40.pdb...
# Processing design12_n9.pdb...
# Processing design8_n52.pdb...
# Processing design18_n22.pdb...
# Processing design28_n54.pdb...
# Processing design13_n50.pdb...
# Processing design12_n40.pdb...
# Processing design14_n13.pdb...
# Processing design25_n32.pdb...
# Processing design15_n61.pdb...
# Processing design27_n48.pdb...
# Processing design13_n36.pdb...
# Processing design3_n18.pdb...
# Processing design29_n49.pdb...
# Processing design20_n10.pdb...
# Processing design9_n54.pdb...
# Processing design30_n37.pdb...
# Processing design12_n13.pdb...
# Processing design29_n21.pdb...
# Processing design7_n51.pdb...
# Processing design8_n8.pdb...
# Processing design17_n22.pdb...
# Processing design29_n11.pdb...
# Processing design9_n40.pdb...
# Processing design14_n53.pdb...
# Processing design24_n16.pdb...
# Processing design17_n16.pdb...
# Processing design2_n40.pdb...
# Processing design19_n56.pdb...
# Processing design9_n51.pdb...
# Processing design28_n41.pdb...
# Processing design10_n48.pdb...
# Processing design26_n21.pdb...
# Processing design14_n41.pdb...
# Processing design9_n52.pdb...
# Processing design14_n38.pdb...
# Processing design2_n25.pdb...
# Processing design1_n56.pdb...
# Processing design23_n28.pdb...
# Processing design22_n49.pdb...
# Processing design19_n29.pdb...
# Processing design25_n36.pdb...
# Processing design24_n58.pdb...
# Processing design28_n22.pdb...
# Processing design11_n32.pdb...
# Processing design2_n37.pdb...
# Processing design9_n26.pdb...
# Processing design31_n17.pdb...
# Processing design24_n26.pdb...
# Processing design16_n55.pdb...
# Processing design15_n32.pdb...
# Processing design1_n18.pdb...
# Processing design14_n43.pdb...
# Processing design9_n32.pdb...
# Processing design6_n41.pdb...
# Processing design24_n57.pdb...
# Processing design6_n58.pdb...
# Processing design27_n50.pdb...
# Processing design2_n21.pdb...
# Processing design5_n6.pdb...
# Processing design13_n13.pdb...
# Processing design13_n3.pdb...
# Processing design27_n42.pdb...
# Processing design1_n46.pdb...
# Processing design23_n30.pdb...
# Processing design4_n8.pdb...
# Processing design12_n52.pdb...
# Processing design5_n15.pdb...
# Processing design19_n25.pdb...
# Processing design15_n0.pdb...
# Processing design24_n1.pdb...
# Processing design19_n45.pdb...
# Processing design19_n20.pdb...
# Processing design2_n3.pdb...
# Processing design20_n63.pdb...
# Processing design19_n58.pdb...
# Processing design11_n34.pdb...
# Processing design31_n60.pdb...
# Processing design14_n25.pdb...
# Processing design12_n47.pdb...
# Processing design14_n33.pdb...
# Processing design12_n43.pdb...
# Processing design30_n43.pdb...
# Processing design5_n61.pdb...
# Processing design13_n52.pdb...
# Processing design30_n46.pdb...
# Processing design12_n36.pdb...
# Processing design28_n47.pdb...
# Processing design19_n44.pdb...
# Processing design18_n5.pdb...
# Processing design9_n60.pdb...
# Processing design15_n16.pdb...
# Processing design20_n32.pdb...
# Processing design25_n12.pdb...
# Processing design5_n0.pdb...
# Processing design3_n3.pdb...
# Processing design3_n43.pdb...
# Processing design16_n51.pdb...
# Processing design21_n57.pdb...
# Processing design3_n62.pdb...
# Processing design27_n5.pdb...
# Processing design27_n12.pdb...
# Processing design24_n30.pdb...
# Processing design29_n52.pdb...
# Processing design0_n29.pdb...
# Processing design31_n50.pdb...
# Processing design14_n18.pdb...
# Processing design7_n56.pdb...
# Processing design31_n14.pdb...
# Processing design8_n57.pdb...
# Processing design12_n29.pdb...
# Processing design27_n26.pdb...
# Processing design7_n38.pdb...
# Processing design4_n60.pdb...
# Processing design28_n31.pdb...
# Processing design16_n63.pdb...
# Processing design26_n54.pdb...
# Processing design21_n47.pdb...
# Processing design28_n63.pdb...
# Processing design7_n20.pdb...
# Processing design29_n26.pdb...
# Processing design8_n25.pdb...
# Processing design19_n37.pdb...
# Processing design25_n60.pdb...
# Processing design18_n1.pdb...
# Processing design26_n46.pdb...
# Processing design26_n4.pdb...
# Processing design14_n1.pdb...
# Processing design3_n11.pdb...
# Processing design19_n7.pdb...
# Processing design20_n39.pdb...
# Processing design10_n44.pdb...
# Processing design26_n6.pdb...
# Processing design21_n27.pdb...
# Processing design2_n14.pdb...
# Processing design11_n18.pdb...
# Processing design27_n16.pdb...
# Processing design12_n35.pdb...
# Processing design14_n29.pdb...
# Processing design16_n31.pdb...
# Processing design21_n15.pdb...
# Processing design9_n27.pdb...
# Processing design24_n3.pdb...
# Processing design1_n29.pdb...
# Processing design17_n5.pdb...
# Processing design30_n44.pdb...
# Processing design28_n34.pdb...
# Processing design19_n60.pdb...
# Processing design30_n56.pdb...
# Processing design11_n54.pdb...
# Processing design16_n9.pdb...
# Processing design25_n52.pdb...
# Processing design21_n56.pdb...
# Processing design5_n29.pdb...
# Processing design11_n19.pdb...
# Processing design21_n32.pdb...
# Processing design28_n38.pdb...
# Processing design16_n27.pdb...
# Processing design17_n11.pdb...
# Processing design3_n22.pdb...
# Processing design29_n23.pdb...
# Processing design29_n24.pdb...
# Processing design10_n27.pdb...
# Processing design15_n54.pdb...
# Processing design7_n24.pdb...
# Processing design8_n50.pdb...
# Processing design27_n0.pdb...
# Processing design1_n59.pdb...
# Processing design28_n9.pdb...
# Processing design16_n16.pdb...
# Processing design12_n15.pdb...
# Processing design17_n31.pdb...
# Processing design6_n4.pdb...
# Processing design29_n6.pdb...
# Processing design20_n22.pdb...
# Processing design14_n36.pdb...
# Processing design27_n53.pdb...
# Processing design3_n33.pdb...
# Processing design27_n2.pdb...
# Processing design31_n23.pdb...
# Processing design6_n37.pdb...
# Processing design2_n47.pdb...
# Processing design26_n35.pdb...
# Processing design8_n44.pdb...
# Processing design18_n28.pdb...
# Processing design5_n62.pdb...
# Processing design15_n9.pdb...
# Processing design16_n8.pdb...
# Processing design20_n4.pdb...
# Processing design30_n34.pdb...
# Processing design15_n25.pdb...
# Processing design23_n3.pdb...
# Processing design8_n3.pdb...
# Processing design6_n16.pdb...
# Processing design11_n26.pdb...
# Processing design14_n46.pdb...
# Processing design11_n13.pdb...
# Processing design8_n7.pdb...
# Processing design27_n33.pdb...
# Processing design26_n12.pdb...
# Processing design2_n2.pdb...
# Processing design21_n7.pdb...
# Processing design23_n41.pdb...
# Processing design19_n2.pdb...
# Processing design14_n31.pdb...
# Processing design24_n53.pdb...
# Processing design4_n36.pdb...
# Processing design0_n57.pdb...
# Processing design12_n4.pdb...
# Processing design5_n17.pdb...
# Processing design16_n43.pdb...
# Processing design26_n58.pdb...
# Processing design6_n52.pdb...
# Processing design2_n44.pdb...
# Processing design25_n30.pdb...
# Processing design28_n35.pdb...
# Processing design22_n5.pdb...
# Processing design29_n9.pdb...
# Processing design17_n27.pdb...
# Processing design6_n54.pdb...
# Processing design24_n32.pdb...
# Processing design15_n37.pdb...
# Processing design13_n55.pdb...
# Processing design21_n12.pdb...
# Processing design27_n8.pdb...
# Processing design27_n37.pdb...
# Processing design15_n44.pdb...
# Processing design0_n25.pdb...
# Processing design25_n57.pdb...
# Processing design17_n15.pdb...
# Processing design9_n59.pdb...
# Processing design13_n25.pdb...
# Processing design4_n31.pdb...
# Processing design0_n50.pdb...
# Processing design23_n55.pdb...
# Processing design10_n39.pdb...
# Processing design9_n62.pdb...
# Processing design8_n21.pdb...
# Processing design3_n23.pdb...
# Processing design1_n33.pdb...
# Processing design23_n48.pdb...
# Processing design0_n10.pdb...
# Processing design29_n22.pdb...
# Processing design15_n13.pdb...
# Processing design26_n1.pdb...
# Processing design8_n48.pdb...
# Processing design8_n36.pdb...
# Processing design16_n47.pdb...
# Processing design29_n47.pdb...
# Processing design20_n58.pdb...
# Processing design13_n21.pdb...
# Processing design26_n5.pdb...
# Processing design6_n63.pdb...
# Processing design12_n11.pdb...
# Processing design15_n53.pdb...
# Processing design2_n0.pdb...
# Processing design11_n4.pdb...
# Processing design19_n59.pdb...
# Processing design18_n35.pdb...
# Processing design8_n12.pdb...
# Processing design0_n16.pdb...
# Processing design1_n27.pdb...
# Processing design14_n37.pdb...
# Processing design4_n14.pdb...
# Processing design8_n10.pdb...
# Processing design7_n63.pdb...
# Processing design7_n46.pdb...
# Processing design5_n32.pdb...
# Processing design14_n54.pdb...
# Processing design29_n40.pdb...
# Processing design18_n12.pdb...
# Processing design27_n38.pdb...
# Processing design29_n45.pdb...
# Processing design10_n12.pdb...
# Processing design29_n25.pdb...
# Processing design15_n7.pdb...
# Processing design22_n12.pdb...
# Processing design18_n51.pdb...
# Processing design17_n8.pdb...
# Processing design23_n18.pdb...
# Processing design15_n41.pdb...
# Processing design23_n63.pdb...
# Processing design19_n3.pdb...
# Processing design4_n4.pdb...
# Processing design15_n48.pdb...
# Processing design27_n31.pdb...
# Processing design24_n18.pdb...
# Processing design9_n38.pdb...
# Processing design18_n37.pdb...
# Processing design11_n60.pdb...
# Processing design24_n54.pdb...
# Processing design26_n15.pdb...
# Processing design12_n6.pdb...
# Processing design2_n1.pdb...
# Processing design30_n27.pdb...
# Processing design17_n43.pdb...
# Processing design9_n45.pdb...
# Processing design31_n46.pdb...
# Processing design6_n28.pdb...
# Processing design24_n22.pdb...
# Processing design5_n42.pdb...
# Processing design23_n12.pdb...
# Processing design10_n13.pdb...
# Processing design6_n49.pdb...
# Processing design8_n45.pdb...
# Processing design2_n7.pdb...
# Processing design19_n41.pdb...
# Processing design4_n46.pdb...
# Processing design1_n63.pdb...
# Processing design21_n3.pdb...
# Processing design18_n3.pdb...
# Processing design9_n12.pdb...
# Processing design0_n39.pdb...
# Processing design20_n25.pdb...
# Processing design17_n26.pdb...
# Processing design18_n52.pdb...
# Processing design13_n19.pdb...
# Processing design20_n54.pdb...
# Processing design6_n18.pdb...
# Processing design23_n56.pdb...
# Processing design31_n21.pdb...
# Processing design25_n34.pdb...
# Processing design24_n0.pdb...
# Processing design30_n33.pdb...
# Processing design2_n5.pdb...
# Processing design18_n13.pdb...
# Processing design13_n62.pdb...
# Processing design1_n15.pdb...
# Processing design13_n1.pdb...
# Processing design20_n46.pdb...
# Processing design17_n0.pdb...
# Processing design26_n30.pdb...
# Processing design27_n22.pdb...
# Processing design8_n39.pdb...
# Processing design3_n53.pdb...
# Processing design25_n59.pdb...
# Processing design14_n44.pdb...
# Processing design1_n28.pdb...
# Processing design16_n26.pdb...
# Processing design30_n47.pdb...
# Processing design4_n16.pdb...
# Processing design14_n9.pdb...
# Processing design11_n31.pdb...
# Processing design7_n34.pdb...
# Processing design20_n6.pdb...
# Processing design6_n32.pdb...
# Processing design5_n26.pdb...
# Processing design10_n16.pdb...
# Processing design1_n50.pdb...
# Processing design7_n62.pdb...
# Processing design25_n23.pdb...
# Processing design31_n62.pdb...
# Processing design25_n2.pdb...
# Processing design6_n55.pdb...
# Processing design27_n47.pdb...
# Processing design19_n57.pdb...
# Processing design1_n9.pdb...
# Processing design9_n58.pdb...
# Processing design12_n16.pdb...
# Processing design19_n8.pdb...
# Processing design20_n30.pdb...
# Processing design7_n49.pdb...
# Processing design7_n30.pdb...
# Processing design8_n33.pdb...
# Processing design13_n46.pdb...
# Processing design20_n44.pdb...
# Processing design24_n63.pdb...
# Processing design16_n62.pdb...
# Processing design1_n51.pdb...
# Processing design1_n22.pdb...
# Processing design28_n51.pdb...
# Processing design11_n20.pdb...
# Processing design25_n41.pdb...
# Processing design10_n60.pdb...
# Processing design26_n39.pdb...
# Processing design9_n28.pdb...
# Processing design15_n6.pdb...
# Processing design20_n53.pdb...
# Processing design11_n6.pdb...
# Processing design21_n18.pdb...
# Processing design7_n28.pdb...
# Processing design23_n50.pdb...
# Processing design29_n4.pdb...
# Processing design0_n53.pdb...
# Processing design24_n20.pdb...
# Processing design13_n17.pdb...
# Processing design13_n10.pdb...
# Processing design2_n39.pdb...
# Processing design31_n58.pdb...
# Processing design8_n27.pdb...
# Processing design24_n9.pdb...
# Processing design21_n6.pdb...
# Processing design30_n15.pdb...
# Processing design24_n21.pdb...
# Processing design26_n61.pdb...
# Processing design31_n63.pdb...
# Processing design6_n53.pdb...
# Processing design9_n42.pdb...
# Processing design2_n50.pdb...
# Processing design13_n30.pdb...
# Processing design13_n57.pdb...
# Processing design22_n61.pdb...
# Processing design26_n55.pdb...
# Processing design22_n30.pdb...
# Processing design30_n57.pdb...
# Processing design15_n33.pdb...
# Processing design21_n41.pdb...
# Processing design25_n27.pdb...
# Processing design10_n2.pdb...
# Processing design19_n46.pdb...
# Processing design11_n29.pdb...
# Processing design3_n59.pdb...
# Processing design16_n2.pdb...
# Processing design31_n35.pdb...
# Processing design0_n60.pdb...
# Processing design18_n20.pdb...
# Processing design24_n55.pdb...
# Processing design17_n33.pdb...
# Processing design4_n7.pdb...
# Processing design10_n37.pdb...
# Processing design27_n62.pdb...
# Processing design1_n0.pdb...
# Processing design11_n33.pdb...
# Processing design24_n61.pdb...
# Processing design7_n36.pdb...
# Processing design23_n36.pdb...
# Processing design21_n21.pdb...
# Processing design23_n22.pdb...
# Processing design31_n42.pdb...
# Processing design23_n45.pdb...
# Processing design4_n26.pdb...
# Processing design23_n15.pdb...
# Processing design26_n19.pdb...
# Processing design6_n0.pdb...
# Processing design0_n27.pdb...
# Processing design28_n10.pdb...
# Processing design1_n19.pdb...
# Processing design4_n22.pdb...
# Processing design25_n62.pdb...
# Processing design31_n31.pdb...
# Processing design18_n44.pdb...
# Processing design19_n26.pdb...
# Processing design18_n50.pdb...
# Processing design15_n22.pdb...
# Processing design1_n37.pdb...
# Processing design7_n50.pdb...
# Processing design14_n50.pdb...
# Processing design11_n61.pdb...
# Processing design27_n11.pdb...
# Processing design19_n21.pdb...
# Processing design19_n36.pdb...
# Processing design14_n63.pdb...
# Processing design11_n11.pdb...
# Processing design2_n26.pdb...
# Processing design25_n16.pdb...
# Processing design21_n22.pdb...
# Processing design21_n53.pdb...
# Processing design1_n17.pdb...
# Processing design6_n60.pdb...
# Processing design26_n34.pdb...
# Processing design7_n23.pdb...
# Processing design3_n61.pdb...
# Processing design21_n54.pdb...
# Processing design29_n33.pdb...
# Processing design8_n20.pdb...
# Processing design25_n25.pdb...
# Processing design17_n38.pdb...
# Processing design3_n32.pdb...
# Processing design18_n21.pdb...
# Processing design20_n8.pdb...
# Processing design24_n5.pdb...
# Processing design11_n44.pdb...
# Processing design8_n41.pdb...
# Processing design15_n49.pdb...
# Processing design0_n47.pdb...
# Processing design12_n61.pdb...
# Processing design25_n51.pdb...
# Processing design1_n21.pdb...
# Processing design25_n20.pdb...
# Processing design11_n49.pdb...
# Processing design19_n62.pdb...
# Processing design6_n56.pdb...
# Processing design31_n12.pdb...
# Processing design13_n15.pdb...
# Processing design22_n40.pdb...
# Processing design11_n17.pdb...
# Processing design28_n27.pdb...
# Processing design7_n53.pdb...
# Processing design22_n35.pdb...
# Processing design12_n41.pdb...
# Processing design19_n50.pdb...
# Processing design24_n8.pdb...
# Processing design5_n39.pdb...
# Processing design9_n47.pdb...
# Processing design20_n56.pdb...
# Processing design16_n24.pdb...
# Processing design17_n36.pdb...
# Processing design12_n58.pdb...
# Processing design27_n4.pdb...
# Processing design7_n15.pdb...
# Processing design19_n23.pdb...
# Processing design31_n45.pdb...
# Processing design25_n7.pdb...
# Processing design21_n10.pdb...
# Processing design25_n39.pdb...
# Processing design18_n46.pdb...
# Processing design7_n60.pdb...
# Processing design12_n25.pdb...
# Processing design1_n11.pdb...
# Processing design16_n50.pdb...
# Processing design31_n4.pdb...
# Processing design2_n20.pdb...
# Processing design4_n25.pdb...
# Processing design2_n58.pdb...
# Processing design22_n9.pdb...
# Processing design7_n26.pdb...
# Processing design19_n9.pdb...
# Processing design0_n26.pdb...
# Processing design5_n36.pdb...
# Processing design9_n56.pdb...
# Processing design18_n56.pdb...
# Processing design13_n22.pdb...
# Processing design30_n19.pdb...
# Processing design10_n0.pdb...
# Processing design4_n33.pdb...
# Processing design28_n24.pdb...
# Processing design9_n24.pdb...
# Processing design12_n5.pdb...
# Processing design4_n48.pdb...
# Processing design23_n20.pdb...
# Processing design24_n40.pdb...
# Processing design17_n35.pdb...
# Processing design4_n10.pdb...
# Processing design8_n16.pdb...
# Processing design1_n26.pdb...
# Processing design21_n0.pdb...
# Processing design0_n46.pdb...
# Processing design10_n3.pdb...
# Processing design15_n4.pdb...
# Processing design29_n35.pdb...
# Processing design25_n28.pdb...
# Processing design11_n37.pdb...
# Processing design8_n29.pdb...
# Processing design7_n44.pdb...
# Processing design18_n42.pdb...
# Processing design10_n10.pdb...
# Processing design26_n43.pdb...
# Processing design18_n57.pdb...
# Processing design0_n34.pdb...
# Processing design24_n37.pdb...
# Processing design14_n55.pdb...
# Processing design4_n41.pdb...
# Processing design27_n36.pdb...
# Processing design15_n47.pdb...
# Processing design14_n42.pdb...
# Processing design28_n53.pdb...
# Processing design4_n54.pdb...
# Processing design25_n8.pdb...
# Processing design1_n53.pdb...
# Processing design17_n39.pdb...
# Processing design25_n17.pdb...
# Processing design14_n28.pdb...
# Processing design2_n35.pdb...
# Processing design29_n3.pdb...
# Processing design24_n44.pdb...
# Processing design31_n54.pdb...
# Processing design13_n18.pdb...
# Processing design16_n21.pdb...
# Processing design31_n13.pdb...
# Processing design23_n1.pdb...
# Processing design26_n49.pdb...
# Processing design18_n32.pdb...
# Processing design29_n18.pdb...
# Processing design22_n36.pdb...
# Processing design16_n20.pdb...
# Processing design11_n35.pdb...
# Processing design31_n28.pdb...
# Processing design8_n11.pdb...
# Processing design21_n1.pdb...
# Processing design17_n47.pdb...
# Processing design6_n22.pdb...
# Processing design9_n63.pdb...
# Processing design10_n22.pdb...
# Processing design0_n15.pdb...
# Processing design8_n55.pdb...
# Processing design4_n29.pdb...
# Processing design14_n15.pdb...
# Processing design9_n3.pdb...
# Processing design21_n55.pdb...
# Processing design25_n0.pdb...
# Processing design17_n42.pdb...
# Processing design11_n53.pdb...
# Processing design2_n24.pdb...
# Processing design30_n61.pdb...
# Processing design5_n12.pdb...
# Processing design8_n40.pdb...
# Processing design12_n17.pdb...
# Processing design4_n37.pdb...
# Processing design25_n6.pdb...
# Processing design16_n14.pdb...
# Processing design28_n26.pdb...
# Processing design13_n56.pdb...
# Processing design26_n57.pdb...
# Processing design3_n45.pdb...
# Processing design11_n55.pdb...
# Processing design10_n59.pdb...
# Processing design9_n29.pdb...
# Processing design5_n45.pdb...
# Processing design1_n36.pdb...
# Processing design19_n34.pdb...
# Processing design20_n3.pdb...
# Processing design20_n12.pdb...
# Processing design27_n27.pdb...
# Processing design18_n61.pdb...
# Processing design21_n58.pdb...
# Processing design30_n9.pdb...
# Processing design24_n62.pdb...
# Processing design20_n37.pdb...
# Processing design15_n27.pdb...
# Processing design31_n16.pdb...
# Processing design7_n11.pdb...
# Processing design14_n27.pdb...
# Processing design5_n48.pdb...
# Processing design8_n47.pdb...
# Processing design30_n54.pdb...
# Processing design4_n17.pdb...
# Processing design2_n45.pdb...
# Processing design11_n24.pdb...
# Processing design12_n38.pdb...
# Processing design12_n51.pdb...
# Processing design8_n54.pdb...
# Processing design27_n55.pdb...
# Processing design22_n54.pdb...
# Processing design25_n35.pdb...
# Processing design31_n27.pdb...
# Processing design20_n26.pdb...
# Processing design24_n10.pdb...
# Processing design22_n23.pdb...
# Processing design22_n42.pdb...
# Processing design13_n44.pdb...
# Processing design2_n11.pdb...
# Processing design0_n54.pdb...
# Processing design10_n55.pdb...
# Processing design2_n8.pdb...
# Processing design28_n2.pdb...
# Processing design3_n27.pdb...
# Processing design4_n23.pdb...
# Processing design17_n59.pdb...
# Processing design22_n45.pdb...
# Processing design8_n56.pdb...
# Processing design30_n14.pdb...
# Processing design27_n23.pdb...
# Processing design2_n55.pdb...
# Processing design5_n25.pdb...
# Processing design2_n4.pdb...
# Processing design2_n42.pdb...
# Processing design9_n34.pdb...
# Processing design13_n11.pdb...
# Processing design2_n32.pdb...
# Processing design27_n30.pdb...
# Processing design3_n12.pdb...
# Processing design22_n41.pdb...
# Processing design17_n54.pdb...
# Processing design19_n31.pdb...
# Processing design16_n0.pdb...
# Processing design2_n13.pdb...
# Processing design15_n28.pdb...
# Processing design7_n9.pdb...
# Processing design14_n7.pdb...
# Processing design30_n1.pdb...
# Processing design14_n34.pdb...
# Processing design0_n12.pdb...
# Processing design6_n27.pdb...
# Processing design3_n28.pdb...
# Processing design20_n5.pdb...
# Processing design28_n29.pdb...
# Processing design29_n57.pdb...
# Processing design24_n27.pdb...
# Processing design0_n36.pdb...
# Processing design11_n8.pdb...
# Processing design18_n59.pdb...
# Processing design27_n43.pdb...
# Processing design4_n3.pdb...
# Processing design29_n8.pdb...
# Processing design16_n22.pdb...
# Processing design31_n15.pdb...
# Processing design6_n19.pdb...
# Processing design17_n2.pdb...
# Processing design5_n58.pdb...
# Processing design3_n19.pdb...
# Processing design23_n29.pdb...
# Processing design13_n12.pdb...
# Processing design0_n21.pdb...
# Processing design8_n2.pdb...
# Processing design8_n32.pdb...
# Processing design27_n3.pdb...
# Processing design22_n63.pdb...
# Processing design22_n34.pdb...
# Processing design16_n18.pdb...
# Processing design22_n0.pdb...
# Processing design12_n2.pdb...
# Processing design15_n50.pdb...
# Processing design29_n10.pdb...
# Processing design0_n32.pdb...
# Processing design30_n13.pdb...
# Processing design30_n41.pdb...
# Processing design25_n55.pdb...
# Processing design31_n38.pdb...
# Processing design16_n17.pdb...
# Processing design31_n24.pdb...
# Processing design30_n36.pdb...
# Processing design15_n59.pdb...
# Processing design24_n36.pdb...
# Processing design12_n45.pdb...
# Processing design4_n11.pdb...
# Processing design5_n49.pdb...
# Processing design4_n2.pdb...
# Processing design7_n4.pdb...
# Processing design31_n2.pdb...
# Processing design0_n63.pdb...
# Processing design28_n20.pdb...
# Processing design12_n20.pdb...
# Processing design7_n16.pdb...
# Processing design3_n0.pdb...
# Processing design28_n62.pdb...
# Processing design11_n52.pdb...
# Processing design12_n53.pdb...
# Processing design31_n49.pdb...
# Processing design15_n1.pdb...
# Processing design6_n15.pdb...
# Processing design8_n30.pdb...
# Processing design23_n51.pdb...
# Processing design3_n47.pdb...
# Processing design3_n7.pdb...
# Processing design17_n14.pdb...
# Processing design19_n42.pdb...
# Processing design19_n19.pdb...
# Processing design30_n59.pdb...
# Processing design17_n44.pdb...
# Processing design28_n55.pdb...
# Processing design15_n58.pdb...
# Processing design21_n25.pdb...
# Processing design12_n63.pdb...
# Processing design28_n50.pdb...
# Processing design13_n35.pdb...
# Processing design25_n46.pdb...
# Processing design3_n25.pdb...
# Processing design21_n5.pdb...
# Processing design2_n23.pdb...
# Processing design5_n19.pdb...
# Processing design31_n52.pdb...
# Processing design11_n40.pdb...
# Processing design14_n47.pdb...
# Processing design6_n40.pdb...
# Processing design16_n58.pdb...
# Processing design3_n20.pdb...
# Processing design18_n60.pdb...
# Processing design10_n47.pdb...
# Processing design2_n60.pdb...
# Processing design7_n37.pdb...
# Processing design2_n18.pdb...
# Processing design6_n50.pdb...
# Processing design21_n9.pdb...
# Processing design22_n58.pdb...
# Processing design30_n45.pdb...
# Processing design13_n51.pdb...
# Processing design17_n30.pdb...
# Processing design12_n57.pdb...
# Processing design20_n21.pdb...
# Processing design11_n22.pdb...
# Processing design4_n53.pdb...
# Processing design4_n6.pdb...
# Processing design6_n29.pdb...
# Processing design29_n59.pdb...
# Processing design7_n2.pdb...
# Processing design21_n46.pdb...
# Processing design29_n43.pdb...
# Processing design20_n52.pdb...
# Processing design19_n14.pdb...
# Processing design12_n26.pdb...
# Processing design3_n42.pdb...
# Processing design25_n58.pdb...
# Processing design22_n7.pdb...
# Processing design20_n43.pdb...
# Processing design18_n24.pdb...
# Processing design31_n40.pdb...
# Processing design8_n9.pdb...
# Processing design7_n19.pdb...
# Processing design5_n52.pdb...
# Processing design28_n0.pdb...
# Processing design26_n41.pdb...
# Processing design18_n18.pdb...
# Processing design3_n4.pdb...
# Processing design6_n26.pdb...
# Processing design7_n21.pdb...
# Processing design23_n16.pdb...
# Processing design16_n38.pdb...
# Processing design7_n1.pdb...
# Processing design14_n32.pdb...
# Processing design24_n59.pdb...
# Processing design0_n35.pdb...
# Processing design14_n26.pdb...
# Processing design18_n16.pdb...
# Processing design29_n20.pdb...
# Processing design16_n34.pdb...
# Processing design10_n8.pdb...
# Processing design20_n34.pdb...
# Processing design21_n19.pdb...
# Processing design17_n63.pdb...
# Processing design10_n63.pdb...
# Processing design27_n40.pdb...
# Processing design2_n48.pdb...
# Processing design10_n51.pdb...
# Processing design20_n48.pdb...
# Processing design7_n22.pdb...
# Processing design0_n1.pdb...
# Processing design21_n42.pdb...
# Processing design9_n10.pdb...
# Processing design16_n42.pdb...
# Processing design7_n61.pdb...
# Processing design28_n16.pdb...
# Processing design17_n9.pdb...
# Processing design26_n9.pdb...
# Processing design26_n14.pdb...
# Processing design22_n39.pdb...
# Processing design6_n57.pdb...
# Processing design14_n59.pdb...
# Processing design1_n14.pdb...
# Processing design25_n4.pdb...
# Processing design17_n28.pdb...
# Processing design21_n38.pdb...
# Processing design22_n55.pdb...
# Processing design7_n59.pdb...
# Processing design12_n21.pdb...
# Processing design22_n27.pdb...
# Processing design21_n17.pdb...
# Processing design28_n1.pdb...
# Processing design5_n63.pdb...
# Processing design30_n30.pdb...
# Processing design29_n37.pdb...
# Processing design3_n30.pdb...
# Processing design24_n56.pdb...
# Processing design23_n37.pdb...
# Processing design26_n31.pdb...
# Processing design19_n38.pdb...
# Processing design14_n24.pdb...
# Processing design23_n61.pdb...
# Processing design19_n52.pdb...
# Processing design20_n16.pdb...
# Processing design30_n48.pdb...
# Processing design17_n17.pdb...
# Processing design9_n53.pdb...
# Processing design19_n39.pdb...
# Processing design17_n7.pdb...
# Processing design13_n4.pdb...
# Processing design20_n49.pdb...
# Processing design9_n57.pdb...
# Processing design4_n63.pdb...
# Processing design23_n6.pdb...
# Processing design31_n48.pdb...
# Processing design9_n16.pdb...
# Processing design4_n32.pdb...
# Processing design29_n36.pdb...
# Processing design30_n21.pdb...
# Processing design14_n35.pdb...
# Processing design17_n21.pdb...
# Processing design15_n14.pdb...
# Processing design22_n48.pdb...
# Processing design9_n55.pdb...
# Processing design29_n56.pdb...
# Processing design12_n22.pdb...
# Processing design31_n3.pdb...
# Processing design0_n11.pdb...
# Processing design13_n7.pdb...
# Processing design27_n61.pdb...
# Processing design28_n13.pdb...
# Processing design7_n25.pdb...
# Processing design14_n45.pdb...
# Processing design25_n13.pdb...
# Processing design0_n8.pdb...
# Processing design17_n32.pdb...
# Processing design12_n44.pdb...
# Processing design23_n10.pdb...
# Processing design30_n51.pdb...
# Processing design9_n48.pdb...
# Processing design19_n35.pdb...
# Processing design21_n2.pdb...
# Processing design9_n0.pdb...
# Processing design13_n60.pdb...
# Processing design18_n8.pdb...
# Processing design5_n60.pdb...
# Processing design21_n11.pdb...
# Processing design28_n15.pdb...
# Processing design30_n25.pdb...
# Processing design5_n41.pdb...
# Processing design13_n32.pdb...
# Processing design24_n60.pdb...
# Processing design11_n3.pdb...
# Processing design10_n36.pdb...
# Processing design0_n56.pdb...
# Processing design2_n22.pdb...
# Processing design26_n63.pdb...
# Processing design20_n60.pdb...
# Processing design18_n41.pdb...
# Processing design21_n51.pdb...
# Processing design20_n18.pdb...
# Processing design8_n60.pdb...
# Processing design25_n3.pdb...
# Processing design20_n45.pdb...
# Processing design6_n24.pdb...
# Processing design10_n21.pdb...
# Processing design5_n9.pdb...
# Processing design31_n18.pdb...
# Processing design17_n25.pdb...
# Processing design1_n47.pdb...
# Processing design23_n17.pdb...
# Processing design9_n15.pdb...
# Processing design17_n34.pdb...
# Processing design10_n43.pdb...
# Processing design20_n28.pdb...
# Processing design30_n32.pdb...
# Processing design24_n13.pdb...
# Processing design0_n58.pdb...
# Processing design6_n2.pdb...
# Processing design6_n7.pdb...
# Processing design11_n45.pdb...
# Processing design5_n37.pdb...
# Processing design10_n41.pdb...
# Processing design15_n26.pdb...
# Processing design31_n55.pdb...
# Processing design20_n29.pdb...
# Processing design26_n38.pdb...
# Processing design0_n40.pdb...
# Processing design7_n58.pdb...
# Processing design26_n17.pdb...
# Processing design11_n46.pdb...
# Processing design1_n58.pdb...
# Processing design8_n35.pdb...
# Processing design8_n24.pdb...
# Processing design7_n57.pdb...
# Processing design9_n44.pdb...
# Processing design27_n63.pdb...
# Processing design0_n2.pdb...
# Processing design13_n2.pdb...
# Processing design8_n49.pdb...
# Processing design20_n61.pdb...
# Processing design2_n57.pdb...
# Processing design1_n52.pdb...
# Processing design30_n58.pdb...
# Processing design25_n47.pdb...
# Processing design1_n16.pdb...
# Processing design9_n23.pdb...
# Processing design5_n38.pdb...
# Processing design27_n54.pdb...
# Processing design6_n25.pdb...
# Processing design5_n10.pdb...
# Processing design7_n18.pdb...
# Processing design15_n55.pdb...
# Processing design18_n33.pdb...
# Processing design30_n16.pdb...
# Processing design19_n53.pdb...
# Processing design6_n6.pdb...
# Processing design19_n27.pdb...
# Processing design17_n50.pdb...
# Processing design25_n24.pdb...
# Processing design13_n26.pdb...
# Processing design6_n1.pdb...
# Processing design3_n56.pdb...
# Processing design3_n14.pdb...
# Processing design9_n25.pdb...
# Processing design27_n35.pdb...
# Processing design16_n11.pdb...
# Processing design13_n39.pdb...
# Processing design28_n19.pdb...
# Processing design3_n21.pdb...
# Processing design0_n20.pdb...
# Processing design15_n12.pdb...
# Processing design22_n60.pdb...
# Processing design0_n23.pdb...
# Processing design22_n33.pdb...
# Processing design26_n3.pdb...
# Processing design27_n28.pdb...
# Processing design19_n0.pdb...
# Processing design0_n17.pdb...
# Processing design23_n58.pdb...
# Processing design15_n62.pdb...
# Processing design27_n49.pdb...
# Processing design12_n30.pdb...
# Processing design20_n19.pdb...
# Processing design0_n62.pdb...
# Processing design29_n30.pdb...
# Processing design1_n7.pdb...
# Processing design7_n42.pdb...
# Processing design15_n63.pdb...
# Processing design19_n15.pdb...
# Processing design10_n18.pdb...
# Processing design9_n36.pdb...
# Processing design8_n4.pdb...
# Processing design24_n52.pdb...
# Processing design31_n32.pdb...
# Processing design30_n6.pdb...
# Processing design11_n50.pdb...
# Processing design9_n5.pdb...
# Processing design6_n46.pdb...
# Processing design14_n5.pdb...
# Processing design8_n51.pdb...
# Processing design18_n58.pdb...
# Processing design19_n47.pdb...
# Processing design10_n57.pdb...
# Processing design0_n5.pdb...
# Processing design2_n36.pdb...
# Processing design23_n27.pdb...
# Processing design1_n40.pdb...
# Processing design29_n55.pdb...
# Processing design22_n6.pdb...
# Processing design29_n44.pdb...
# Processing design19_n24.pdb...
# Processing design12_n0.pdb...
# Processing design25_n43.pdb...
# Processing design24_n48.pdb...
# Processing design7_n45.pdb...
# Processing design24_n6.pdb...
# Processing design11_n14.pdb...
# Processing design24_n23.pdb...
# Processing design24_n49.pdb...
# Processing design7_n17.pdb...
# Processing design1_n20.pdb...
# Processing design18_n4.pdb...
# Processing design29_n27.pdb...
# Processing design2_n53.pdb...
# Processing design8_n46.pdb...
# Processing design17_n12.pdb...
# Processing design21_n34.pdb...
# Processing design24_n35.pdb...
# Processing design4_n57.pdb...
# Processing design3_n24.pdb...
# Processing design1_n54.pdb...
# Processing design15_n17.pdb...
# Processing design20_n2.pdb...
# Processing design19_n54.pdb...
# Processing design16_n52.pdb...
# Processing design7_n41.pdb...
# Processing design8_n19.pdb...
# Processing design8_n63.pdb...
# Processing design18_n39.pdb...
# Processing design11_n38.pdb...
# Processing design19_n16.pdb...
# Processing design28_n23.pdb...
# Processing design28_n32.pdb...
# Processing design3_n31.pdb...
# Processing design17_n52.pdb...
# Processing design30_n52.pdb...
# Processing design14_n56.pdb...
# Processing design26_n16.pdb...
# Processing design11_n16.pdb...
# Processing design2_n41.pdb...
# Processing design14_n10.pdb...
# Processing design29_n41.pdb...
# Processing design20_n23.pdb...
# Processing design0_n37.pdb...
# Processing design14_n11.pdb...
# Processing design2_n9.pdb...
# Processing design23_n8.pdb...
# Processing design5_n51.pdb...
# Processing design9_n31.pdb...
# Processing design31_n26.pdb...
# Processing design31_n57.pdb...
# Processing design30_n3.pdb...
# Processing design5_n46.pdb...
# Processing design11_n21.pdb...
# Processing design18_n63.pdb...
# Processing design2_n12.pdb...
# Processing design23_n40.pdb...
# Processing design24_n7.pdb...
# Processing design25_n42.pdb...
# Processing design31_n56.pdb...
# Processing design20_n33.pdb...
# Processing design29_n5.pdb...
# Processing design19_n22.pdb...
# Processing design8_n62.pdb...
# Processing design26_n37.pdb...
# Processing design5_n33.pdb...
# Processing design14_n0.pdb...
# Processing design9_n13.pdb...
# Processing design31_n1.pdb...
# Processing design13_n41.pdb...
# Processing design15_n46.pdb...
# Processing design14_n4.pdb...
# Processing design8_n28.pdb...
# Processing design25_n61.pdb...
# Processing design27_n34.pdb...
# Processing design31_n29.pdb...
# Processing design7_n48.pdb...
# Processing design30_n62.pdb...
# Processing design12_n8.pdb...
# Processing design8_n37.pdb...
# Processing design29_n42.pdb...
# Processing design16_n49.pdb...
# Processing design19_n33.pdb...
# Processing design2_n61.pdb...
# Processing design14_n20.pdb...
# Processing design15_n8.pdb...
# Processing design21_n61.pdb...
# Processing design4_n55.pdb...
# Processing design4_n44.pdb...
# Processing design13_n49.pdb...
# Processing design18_n55.pdb...
# Processing design22_n31.pdb...
# Processing design28_n3.pdb...
# Processing design11_n39.pdb...
# Processing design19_n55.pdb...
# Processing design17_n58.pdb...
# Processing design22_n25.pdb...
# Processing design5_n20.pdb...
# Processing design8_n42.pdb...
# Processing design8_n58.pdb...
# Processing design20_n15.pdb...
# Processing design23_n11.pdb...
# Processing design21_n35.pdb...
# Processing design17_n56.pdb...
# Processing design1_n48.pdb...
# Processing design3_n13.pdb...
# Processing design17_n13.pdb...
# Processing design24_n17.pdb...
# Processing design19_n49.pdb...
# Processing design24_n39.pdb...
# Processing design9_n4.pdb...
# Processing design29_n12.pdb...
# Processing design2_n19.pdb...
# Processing design5_n59.pdb...
# Processing design5_n47.pdb...
# Processing design6_n30.pdb...
# Processing design16_n7.pdb...
# Processing design1_n31.pdb...
# Processing design11_n47.pdb...
# Processing design11_n63.pdb...
# Processing design16_n1.pdb...
# Processing design12_n62.pdb...
# Processing design6_n10.pdb...
# Processing design5_n4.pdb...
# Processing design6_n11.pdb...
# Processing design16_n37.pdb...
# Processing design21_n23.pdb...
# Processing design26_n47.pdb...
# Processing design29_n32.pdb...
# Processing design1_n55.pdb...
# Processing design25_n11.pdb...
# Processing design24_n2.pdb...
# Processing design17_n61.pdb...
# Processing design8_n13.pdb...
# Processing design13_n58.pdb...
# Processing design25_n9.pdb...
# Processing design1_n43.pdb...
# Processing design27_n10.pdb...
# Processing design30_n50.pdb...
# Processing design1_n60.pdb...
# Processing design22_n10.pdb...
# Processing design9_n21.pdb...
# Processing design20_n55.pdb...
# Processing design3_n48.pdb...
# Processing design18_n36.pdb...
# Processing design1_n6.pdb...
# Processing design9_n46.pdb...
# Processing design15_n31.pdb...
# Processing design10_n14.pdb...
# Processing design30_n60.pdb...
# Processing design26_n20.pdb...
# Processing design31_n41.pdb...
# Processing design18_n45.pdb...
# Processing design14_n22.pdb...
# Processing design16_n12.pdb...
# Processing design25_n19.pdb...
# Processing design29_n14.pdb...
# Processing design4_n0.pdb...
# Processing design0_n31.pdb...
# Processing design22_n28.pdb...
# Processing design25_n44.pdb...
# Processing design13_n28.pdb...
# Processing design24_n51.pdb...
# Processing design25_n22.pdb...
# Processing design18_n19.pdb...
# Processing design23_n57.pdb...
# Processing design20_n42.pdb...
# Processing design8_n1.pdb...
# Processing design3_n10.pdb...
# Processing design31_n43.pdb...
# Processing design27_n24.pdb...
# Processing design14_n16.pdb...
# Processing design0_n43.pdb...
# Processing design24_n24.pdb...
# Processing design12_n37.pdb...
# Processing design27_n1.pdb...
# Processing design16_n23.pdb...
# Processing design12_n32.pdb...
# Processing design15_n11.pdb...
# Processing design26_n53.pdb...
# Processing design0_n55.pdb...
# Processing design26_n11.pdb...
# Processing design26_n8.pdb...
# Processing design17_n20.pdb...
# Processing design3_n38.pdb...
# Processing design1_n1.pdb...
# Processing design6_n47.pdb...
# Processing design15_n34.pdb...
# Processing design6_n51.pdb...
# Processing design27_n9.pdb...
# Processing design30_n12.pdb...
# Processing design27_n58.pdb...
# Processing design9_n11.pdb...
# Processing design16_n19.pdb...
# Processing design25_n33.pdb...
# Processing design2_n51.pdb...
# Processing design9_n6.pdb...
# Processing design29_n2.pdb...
# Processing design27_n44.pdb...
# Processing design30_n39.pdb...
# Processing design19_n17.pdb...
# Processing design29_n53.pdb...
# Processing design9_n49.pdb...
# Processing design24_n47.pdb...
# Processing design26_n18.pdb...
# Processing design3_n1.pdb...
# Processing design13_n47.pdb...
# Processing design28_n58.pdb...
# Processing design4_n15.pdb...
# Processing design4_n18.pdb...
# Processing design23_n62.pdb...
# Processing design13_n24.pdb...
# Processing design31_n53.pdb...
# Processing design28_n25.pdb...
# Processing design24_n43.pdb...
# Processing design4_n27.pdb...
# Processing design21_n33.pdb...
# Processing design29_n15.pdb...
# Processing design12_n1.pdb...
# Processing design4_n12.pdb...
# Processing design16_n33.pdb...
# Processing design20_n40.pdb...
# Processing design17_n60.pdb...
# Processing design0_n42.pdb...
# Processing design14_n14.pdb...
# Processing design7_n12.pdb...
# Processing design10_n49.pdb...
# Processing design13_n23.pdb...
# Processing design31_n33.pdb...
# Processing design25_n40.pdb...
# Processing design30_n28.pdb...
# Processing design29_n46.pdb...
# Processing design21_n48.pdb...
# Processing design12_n56.pdb...
# Processing design3_n63.pdb...
# Processing design15_n24.pdb...
# Processing design31_n8.pdb...
# Processing design26_n27.pdb...
# Processing design13_n20.pdb...
# Processing design23_n2.pdb...
# Processing design7_n39.pdb...
# Processing design10_n33.pdb...
# Processing design1_n12.pdb...
# Processing design26_n24.pdb...
# Processing design5_n18.pdb...
# Processing design21_n8.pdb...
# Processing design23_n54.pdb...
# Processing design21_n63.pdb...
# Processing design30_n63.pdb...
# Processing design23_n13.pdb...
# Processing design19_n10.pdb...
# Processing design15_n52.pdb...
# Processing design6_n36.pdb...
# Processing design28_n43.pdb...
# Processing design23_n42.pdb...
# Processing design13_n53.pdb...
# Processing design3_n36.pdb...
# Processing design0_n18.pdb...
# Processing design23_n39.pdb...
# Processing design13_n59.pdb...
# Processing design16_n41.pdb...
# Processing design6_n38.pdb...
# Processing design10_n5.pdb...
# Processing design3_n51.pdb...
# Processing design13_n6.pdb...
# Processing design25_n48.pdb...
# Processing design21_n30.pdb...
# Processing design26_n0.pdb...
# Processing design28_n57.pdb...
# Processing design28_n30.pdb...
# Processing design14_n51.pdb...
# Processing design17_n29.pdb...
# Processing design15_n19.pdb...
# Processing design11_n51.pdb...
# Processing design23_n32.pdb...
# Processing design18_n25.pdb...
# Processing design2_n28.pdb...
# Processing design14_n17.pdb...
# Processing design10_n15.pdb...
# Processing design10_n54.pdb...
# Processing design13_n31.pdb...
# Processing design11_n7.pdb...
# Processing design1_n35.pdb...
# Processing design1_n32.pdb...
# Processing design30_n7.pdb...
# Processing design16_n36.pdb...
# Processing design7_n32.pdb...
# Processing design8_n0.pdb...
# Processing design5_n2.pdb...
# Processing design26_n50.pdb...
# Processing design3_n9.pdb...
# Processing design16_n15.pdb...
# Processing design14_n57.pdb...
# Processing design20_n1.pdb...
# Processing design21_n24.pdb...
# Processing design9_n20.pdb...
# Processing design5_n5.pdb...
# Processing design0_n38.pdb...
# Processing design8_n38.pdb...
# Saved structure analysis results to /content/drive/MyDrive/PDB-files/all_pdb_2MBO-12/structure_analysis.csv
# Downloaded structure_analysis.csv to your computer
# Merging with AF2 scores from /content/drive/MyDrive/PDB-files/all_pdb_2MBO-12/af2_scores.csv
# Saved combined results to /content/drive/MyDrive/PDB-files/all_pdb_2MBO-12/combined_analysis.csv
#
# Generating plots...
# Downloaded combined_analysis.csv to your computer
# Downloaded plot_hydrogen_bonds.png
# Downloaded plot_hydrophobic_contacts.png
# Downloaded plot_buried_surface_area.png

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
