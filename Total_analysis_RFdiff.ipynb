# %% [markdown]
# <a href="https://colab.research.google.com/github/eoinleen/protein-design-final-dir/blob/main/Total_analysis_RFdiff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
RFdiffusion Structure Analysis and Sequence Extraction Tool
========================================================
Created: January 31, 2025
Authors: Original Analysis - Dr. Eoin Leen, University of Leeds
         Visualization & Integration - Claude AI & Dr. Eoin Leen
Version: 2.0

Purpose:
--------
Combined pipeline for:
1. Structural analysis of PDB files
2. AF2 score visualization
3. Sequence extraction and formatting
4. Generation of publication-ready visualizations

Input Required:
-------------
1. Directory containing PDB files
2. af2_scores.csv file in same directory containing:
   - design: Design number
   - n: Sequence number
   - seq: Sequences in format "sequence1/sequence2"
   - i_pae: iPAE scores
   - Other AF2 metrics

Output Generated:
---------------
1. PowerPoint presentation with:
   - Slide 1: Structure-function correlation plots
   - Slide 2: iPAE score visualization
   - Slide 3: Top 10 sequences by iPAE score
2. Combined FASTA file with all sequences
3. CSV file with combined structural analysis

Analysis Parameters:
------------------
Structure Analysis Cutoffs:
1. Hydrogen Bonds:
   - Distance cutoff: O-N distance < 3.5 Å
   - Calculated between backbone atoms only
   - Only inter-chain H-bonds counted

2. Salt Bridges:
   - Distance cutoff: < 4.0 Å between any atoms of residue pairs
   - Residue pairs considered:
     * Acidic: ASP, GLU
     * Basic: LYS, ARG, HIS
   - Only inter-chain salt bridges counted

3. Hydrophobic Contacts:
   - Distance cutoff: < 5.0 Å between any atoms of residue pairs
   - Hydrophobic residues considered:
     * ALA, VAL, LEU, ILE, MET, PHE, TRP, PRO
   - Only inter-chain contacts counted

4. Buried Surface Area:
   - Calculated using FreeSASA algorithm
   - Uses default atomic radii from FreeSASA (based on NACCESS/RSA)
   - Process:
     * First calculates SASA for entire complex
     * Then calculates SASA for each chain individually
     * BSA = (Sum of individual chain SASAs - Complex SASA) / 2
   - Units: Å²
   - Inter-chain burial only (interface area)
   - Probe radius: 1.4 Å (water molecule)
   - Resolution: 100 points/atom (FreeSASA default)

Usage:
-----
1. Mount Google Drive in Colab
2. Update pdb_directory path
3. Run script
"""

# Install required packages
# !pip install -q biopython pandas freesasa numpy matplotlib seaborn python-pptx plotly kaleido

# Import required libraries
import os
import sys
import time
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files, drive
from pathlib import Path
from typing import Dict, List, Optional, Tuple, Any
from Bio import PDB
from Bio.PDB.PDBIO import PDBIO
from Bio.PDB.Polypeptide import is_aa
from Bio.PDB.Structure import Structure
import freesasa
import numpy as np
import seaborn as sns
from pptx import Presentation
from pptx.util import Inches, Cm, Pt
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Custom exception for structure validation
class StructureValidationError(Exception):
    pass
# ===============================
# Structure Analysis Functions
# ===============================

def validate_pdb_file(file_path: str) -> bool:
    """Validates if file exists and has proper PDB format."""
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"PDB file not found: {file_path}")
    try:
        with open(file_path, 'r') as f:
            first_line = f.readline()
            if not any(marker in first_line for marker in ['HEADER', 'ATOM', 'MODEL']):
                raise StructureValidationError(f"Invalid PDB: {file_path}")
    except UnicodeDecodeError:
        raise StructureValidationError(f"Not a valid text file: {file_path}")
    return True

def safe_structure_load(parser: PDB.PDBParser, file_path: str) -> Optional[Structure]:
    """Safely loads PDB structure with error handling."""
    try:
        validate_pdb_file(file_path)
        structure = parser.get_structure('protein', file_path)
        if not list(structure.get_models()):
            raise StructureValidationError("No models")
        if not list(list(structure.get_models())[0].get_chains()):
            raise StructureValidationError("No chains")
        return structure
    except Exception as e:
        print(f"Error loading {file_path}: {str(e)}")
        return None

def calculate_buried_surface_area(pdb_file: str) -> Tuple[Optional[float], Optional[Dict[str, float]]]:
    """Calculates buried surface area between chains."""
    parser = PDB.PDBParser(QUIET=True)
    structure = safe_structure_load(parser, pdb_file)
    if not structure:
        return None, None
    try:
        chains = list(structure.get_chains())
        if len(chains) < 2:
            print(f"Warning: {pdb_file} has fewer than 2 chains")
            return None, None

        combined_structure = freesasa.Structure(pdb_file)
        result = freesasa.calc(combined_structure)
        total_area = result.totalArea()

        chain_areas = {}
        io = PDBIO()
        temp_files = []

        for chain in chains:
            new_structure = PDB.Structure.Structure('temp')
            new_model = PDB.Model.Model(0)
            new_structure.add(new_model)
            new_model.add(chain.copy())

            temp_file = f"temp_chain_{chain.id}.pdb"
            temp_files.append(temp_file)

            io.set_structure(new_structure)
            io.save(temp_file)

            chain_structure = freesasa.Structure(temp_file)
            chain_result = freesasa.calc(chain_structure)
            chain_areas[chain.id] = chain_result.totalArea()

        for temp_file in temp_files:
            if os.path.exists(temp_file):
                os.remove(temp_file)

        total_individual_area = sum(chain_areas.values())
        buried_surface_area = abs(total_individual_area - total_area) / 2
        return buried_surface_area, chain_areas

    except Exception as e:
        print(f"Error calculating BSA for {pdb_file}: {str(e)}")
        return None, None

def calculate_hydrogen_bonds(structure: Structure) -> int:
    """Calculates number of hydrogen bonds between chains."""
    try:
        h_bonds = 0
        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id >= chain2.id:
                    continue
                for res1 in chain1.get_residues():
                    if not is_aa(res1):
                        continue
                    for res2 in chain2.get_residues():
                        if not is_aa(res2):
                            continue
                        if 'O' in res1 and 'N' in res2:
                            distance = res1['O'] - res2['N']
                            if distance < 3.5:
                                h_bonds += 1
        return h_bonds
    except Exception as e:
        print(f"Error calculating H-bonds: {str(e)}")
        return 0
def calculate_hydrophobic_contacts(structure: Structure) -> int:
    """
    Calculates number of hydrophobic contacts between chains.
    Considers residues ALA, VAL, LEU, ILE, MET, PHE, TRP, PRO.
    Contact is counted if distance < 5.0 Å.
    """
    try:
        hydrophobic_residues = {'ALA', 'VAL', 'LEU', 'ILE', 'MET', 'PHE', 'TRP', 'PRO'}
        contacts = 0
        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id >= chain2.id:
                    continue
                for res1 in chain1.get_residues():
                    if not is_aa(res1) or res1.get_resname() not in hydrophobic_residues:
                        continue
                    for res2 in chain2.get_residues():
                        if not is_aa(res2) or res2.get_resname() not in hydrophobic_residues:
                            continue
                        min_distance = float('inf')
                        for atom1 in res1.get_atoms():
                            for atom2 in res2.get_atoms():
                                distance = atom1 - atom2
                                min_distance = min(min_distance, distance)
                        if min_distance < 5.0:
                            contacts += 1
        return contacts
    except Exception as e:
        print(f"Error calculating hydrophobic contacts: {str(e)}")
        return 0

def calculate_salt_bridges(structure: Structure) -> int:
    """
    Calculates number of salt bridges between chains.
    Salt bridge is counted between ASP/GLU and LYS/ARG/HIS if distance < 4.0 Å.
    """
    try:
        acidic = {'ASP', 'GLU'}
        basic = {'LYS', 'ARG', 'HIS'}
        salt_bridges = 0
        for chain1 in structure.get_chains():
            for chain2 in structure.get_chains():
                if chain1.id >= chain2.id:
                    continue
                for res1 in chain1.get_residues():
                    if not is_aa(res1):
                        continue
                    res1_name = res1.get_resname()
                    for res2 in chain2.get_residues():
                        if not is_aa(res2):
                            continue
                        res2_name = res2.get_resname()
                        if ((res1_name in acidic and res2_name in basic) or
                            (res1_name in basic and res2_name in acidic)):
                            min_distance = float('inf')
                            for atom1 in res1.get_atoms():
                                for atom2 in res2.get_atoms():
                                    distance = atom1 - atom2
                                    min_distance = min(min_distance, distance)
                            if min_distance < 4.0:
                                salt_bridges += 1
        return salt_bridges
    except Exception as e:
        print(f"Error calculating salt bridges: {str(e)}")
        return 0

def save_results_as_df(results: List[Dict[str, Any]], output_file: str) -> pd.DataFrame:
    """
    Converts analysis results to DataFrame and saves to CSV.
    Extracts design and variant numbers from filenames.
    """
    analysis_data = []
    for result in results:
        filename = result['file_name'].replace('.pdb', '')
        try:
            design_num = int(filename.split('design')[1].split('_')[0])
            variant_num = int(filename.split('_n')[1])
            analysis_data.append({
                'design': design_num,
                'n': variant_num,
                'buried_surface_area': result['buried_surface_area'] if result['buried_surface_area'] else 0,
                'hydrogen_bonds': result['hydrogen_bonds'],
                'hydrophobic_contacts': result['hydrophobic_contacts'],
                'salt_bridges': result['salt_bridges']
            })
        except Exception as e:
            print(f"Error parsing filename {filename}: {str(e)}")
            continue

    df = pd.DataFrame(analysis_data)
    df = df.sort_values(['design', 'n']).reset_index(drop=True)
    df.to_csv(output_file, index=False)
    print(f"Saved structure analysis to {output_file}")
    return df

def merge_with_af2_scores(structure_df: pd.DataFrame, af2_scores_file: str) -> pd.DataFrame:
    """Merges structural analysis results with AF2 scores."""
    af2_df = pd.read_csv(af2_scores_file)
    merged_df = pd.merge(af2_df, structure_df, on=['design', 'n'], how='left')
    merged_df = merged_df.sort_values(['design', 'n']).reset_index(drop=True)
    return merged_df
# ===============================
# Visualization and Sequence Functions
# ===============================

def create_pptx_plots(df: pd.DataFrame, output_dir: str, timestamp: str):
    """
    Creates PowerPoint presentation with three slides:
    1. Structure-function correlation plots
    2. iPAE visualization
    3. Top 10 lowest iPAE sequences
    """
    # Initialize presentation
    prs = Presentation()
    prs.slide_width = Cm(21)
    prs.slide_height = Cm(29.7)

    # First slide - correlation plots
    slide1 = prs.slides.add_slide(prs.slide_layouts[5])

    fig, axes = plt.subplots(3, 2, figsize=(8.27, 11.69))
    axes = axes.flatten()

    y_vars = ['i_ptm', 'rmsd', 'buried_surface_area',
              'hydrogen_bonds', 'hydrophobic_contacts', 'salt_bridges']
    titles = ['iPTM', 'RMSD (Å)', 'Buried Surface Area (Å²)',
             '# of Hydrogen Bonds', '# of Hydrophobic Contacts', '# of Salt Bridges']

    for ax, y_var, title in zip(axes, y_vars, titles):
        sns.scatterplot(data=df, x='i_pae', y=y_var, ax=ax, color='black', marker='x', s=16)
        ax.set_xlabel('i_PAE')
        ax.set_ylabel(title)
        ax.set_title(title)
        ax.set_facecolor('white')

    fig.patch.set_facecolor('white')
    plt.tight_layout()

    temp_img1 = os.path.join(output_dir, 'temp_plots1.png')
    plt.savefig(temp_img1, bbox_inches='tight', dpi=300, facecolor='white')
    plt.close()

    left = Cm(2)
    top = Cm(2)
    slide1.shapes.add_picture(temp_img1, left, top)

    # Second slide - iPAE visualization
    slide2 = prs.slides.add_slide(prs.slide_layouts[5])

    fig = make_subplots(
        rows=4,
        cols=1,
        vertical_spacing=0.08,
        subplot_titles=[f"Designs {i*8}-{(i+1)*8-1}" for i in range(4)]
    )

    rows_per_subplot = 512  # 8 designs × 64 sequences = 512 rows per subplot
    colors = ['black', 'red']

    for i in range(4):
        start_idx = i * rows_per_subplot
        end_idx = start_idx + rows_per_subplot
        chunk = df.iloc[start_idx:end_idx].copy()

        for design_num in chunk['design'].unique():
            mask = chunk['design'] == design_num
            color = colors[design_num % 2]

            fig.add_trace(
                go.Bar(
                    x=chunk[mask].index,
                    y=chunk[mask]['i_pae'],
                    showlegend=False,
                    marker_color=color,
                    width=1,
                ),
                row=i+1,
                col=1
            )

        fig.update_yaxes(
            range=[0, 30],
            title_text='iPAE' if i == 1 else None,
            row=i+1,
            col=1
        )

        design_numbers = sorted(chunk['design'].unique())
        fig.update_xaxes(
            tickmode='array',
            ticktext=design_numbers,
            tickvals=[start_idx + (j*64) + 32 for j in range(len(design_numbers))],
            row=i+1,
            col=1,
            title_text='Design Number' if i == 3 else None
        )

    fig.update_layout(
        title='iPAE Scores by Design Number and Sequence (Scale: 0-30)',
        height=1000,
        width=1200,
        showlegend=False,
        margin=dict(t=50, b=50, r=150, l=50),
        paper_bgcolor='white',
        plot_bgcolor='white'
    )

    temp_img2 = os.path.join(output_dir, 'temp_plots2.png')
    fig.write_image(temp_img2)

    left = Cm(1)
    top = Cm(1)
    slide2.shapes.add_picture(temp_img2, left, top)

    # Third slide - Top 10 lowest i_PAE sequences
    slide3 = prs.slides.add_slide(prs.slide_layouts[5])

    # Get top 10 lowest i_PAE sequences
    top_10_sequences = df.nsmallest(10, 'i_pae')[['design', 'n', 'i_pae', 'seq']]

    # Add title to slide
    title = slide3.shapes.title
    title.text = "Top 10 Sequences (Lowest i_PAE Scores)"

    # Create text box for sequences
    left = Cm(2)
    top = Cm(4)
    width = Cm(17)
    height = Cm(20)
    textbox = slide3.shapes.add_textbox(left, top, width, height)

    # Format and add sequences
    text_frame = textbox.text_frame
    text_frame.clear()

    for _, row in top_10_sequences.iterrows():
        sequence = row['seq'].split('/')[1].strip()
        p = text_frame.add_paragraph()
        p.text = f">d{row['design']}n{row['n']} (i_PAE: {row['i_pae']:.4f})\n{sequence}"
        p.font.name = 'Courier New'
        p.font.size = Pt(9)

    # Save PowerPoint
    output_basename = os.path.basename(output_dir)
    pptx_path = os.path.join(output_dir, f"{output_basename}_{timestamp}_analysis.pptx")
    prs.save(pptx_path)

    # Clean up temporary files
    os.remove(temp_img1)
    os.remove(temp_img2)
    print(f"Saved PowerPoint to {pptx_path}")

def save_sequences_fasta(df: pd.DataFrame, output_dir: str, timestamp: str):
    """
    Extracts sequences after '/' and saves to combined FASTA file.
    """
    output_basename = os.path.basename(output_dir)
    fasta_path = os.path.join(output_dir, f"{output_basename}_{timestamp}_sequences.fasta")

    with open(fasta_path, 'w') as f:
        for _, row in df.iterrows():
            sequence = row['seq'].split('/')[1].strip()
            header = f">d{row['design']}n{row['n']}"
            f.write(f"{header}\n{sequence}\n")

    print(f"Saved combined FASTA file to {fasta_path}")
# ===============================
# Main Processing Function
# ===============================

def process_multiple_pdb_files(pdb_directory: str, af2_scores_file: str = None) -> pd.DataFrame:
    """
    Main processing function that:
    1. Analyzes all PDB files in directory
    2. Merges with AF2 scores
    3. Generates visualizations and outputs
    """
    if not os.path.exists(pdb_directory):
        raise FileNotFoundError(f"Directory not found: {pdb_directory}")

    # Get timestamp for file naming
    timestamp = time.strftime("%y%m%d")

    # Initialize results
    results = []
    parser = PDB.PDBParser(QUIET=True)
    pdb_files = [f for f in os.listdir(pdb_directory) if f.endswith('.pdb')]

    if not pdb_files:
        print(f"No PDB files found in {pdb_directory}")
        return pd.DataFrame()

    print(f"Processing {len(pdb_files)} PDB files...")
    total_files = len(pdb_files)

    # Process each PDB file
    for idx, file_name in enumerate(pdb_files, 1):
        pdb_file = os.path.join(pdb_directory, file_name)
        print(f"Processing file {idx}/{total_files}: {file_name}")

        structure = safe_structure_load(parser, pdb_file)
        if not structure:
            continue

        # Calculate structural parameters
        buried_surface_area, chain_areas = calculate_buried_surface_area(pdb_file)
        h_bonds = calculate_hydrogen_bonds(structure)
        hydrophobic = calculate_hydrophobic_contacts(structure)
        salt_bridges = calculate_salt_bridges(structure)

        results.append({
            'file_name': file_name,
            'buried_surface_area': buried_surface_area,
            'hydrogen_bonds': h_bonds,
            'hydrophobic_contacts': hydrophobic,
            'salt_bridges': salt_bridges,
            'chain_areas': chain_areas
        })

    # Save structural analysis
    output_basename = os.path.basename(pdb_directory)
    structure_csv = os.path.join(pdb_directory, f"{output_basename}_{timestamp}_structure.csv")
    structure_df = save_results_as_df(results, structure_csv)

    # If AF2 scores exist, merge and create visualizations
    if af2_scores_file and os.path.exists(af2_scores_file):
        print(f"Merging with AF2 scores from {af2_scores_file}")
        final_df = merge_with_af2_scores(structure_df, af2_scores_file)

        # Save combined analysis
        combined_csv = os.path.join(pdb_directory, f"{output_basename}_{timestamp}_combined.csv")
        final_df.to_csv(combined_csv, index=False)
        print(f"Saved combined results to {combined_csv}")

        # Create PowerPoint plots
        create_pptx_plots(final_df, pdb_directory, timestamp)

        # Save sequences to FASTA
        save_sequences_fasta(final_df, pdb_directory, timestamp)

        return final_df
    return structure_df

# ===============================
# Main Execution
# ===============================

if __name__ == "__main__":
    # Mount Google Drive
    drive.mount('/content/drive')

    # Set directory containing PDB files and AF2 scores
    pdb_directory = '/content/drive/MyDrive/PDB-files/202501xx/3NOB-70-110-all_pdb'  # Update this path
    af2_scores_path = os.path.join(pdb_directory, 'af2_scores.csv')

    if not os.path.exists(af2_scores_path):
        af2_scores_path = None
        print("No AF2 scores file found - will generate structure analysis only")

    print("\nStarting analysis...")
    print(f"Processing PDB files from: {pdb_directory}")

    try:
        results_df = process_multiple_pdb_files(pdb_directory, af2_scores_path)
        print("\nAnalysis completed successfully!")
    except Exception as e:
        print(f"\nError during analysis: {str(e)}")
        raise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.1/270.1 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 12.9 MB/s eta 0:00:00
#   Building wheel for freesasa (setup.py) ... done
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Starting analysis...
# Processing PDB files from: /content/drive/MyDrive/PDB-files/202501xx/3NOB-70-110-all_pdb
# Processing 2048 PDB files...
# Processing file 1/2048: design12_n60.pdb
# Processing file 2/2048: design27_n28.pdb
# Processing file 3/2048: design24_n27.pdb
# Processing file 4/2048: design18_n55.pdb
# Processing file 5/2048: design31_n45.pdb
# Processing file 6/2048: design31_n26.pdb
# Processing file 7/2048: design1_n54.pdb
# Processing file 8/2048: design15_n62.pdb
# Processing file 9/2048: design19_n59.pdb
# Processing file 10/2048: design28_n57.pdb
# Processing file 11/2048: design22_n56.pdb
# Processing file 12/2048: design5_n19.pdb
# Processing file 13/2048: design5_n16.pdb
# Processing file 14/2048: design16_n5.pdb
# Processing file 15/2048: design27_n26.pdb
# Processing file 16/2048: design30_n28.pdb
# Processing file 17/2048: design23_n23.pdb
# Processing file 18/2048: design20_n59.pdb
# Processing file 19/2048: design2_n49.pdb
# Processing file 20/2048: design25_n40.pdb
# Processing file 21/2048: design3_n63.pdb
# Processing file 22/2048: design12_n52.pdb
# Processing file 23/2048: design8_n7.pdb
# Processing file 24/2048: design5_n48.pdb
# Processing file 25/2048: design31_n10.pdb
# Processing file 26/2048: design31_n6.pdb
# Processing file 27/2048: design10_n45.pdb
# Processing file 28/2048: design2_n34.pdb
# Processing file 29/2048: design15_n28.pdb
# Processing file 30/2048: design31_n33.pdb
# Processing file 31/2048: design24_n25.pdb
# Processing file 32/2048: design12_n22.pdb
# Processing file 33/2048: design22_n62.pdb
# Processing file 34/2048: design17_n20.pdb
# Processing file 35/2048: design5_n31.pdb
# Processing file 36/2048: design5_n32.pdb
# Processing file 37/2048: design6_n43.pdb
# Processing file 38/2048: design9_n27.pdb
# Processing file 39/2048: design28_n44.pdb
# Processing file 40/2048: design29_n53.pdb
# Processing file 41/2048: design9_n16.pdb
# Processing file 42/2048: design7_n47.pdb
# Processing file 43/2048: design0_n41.pdb
# Processing file 44/2048: design0_n7.pdb
# Processing file 45/2048: design16_n49.pdb
# Processing file 46/2048: design10_n14.pdb
# Processing file 47/2048: design28_n11.pdb
# Processing file 48/2048: design13_n33.pdb
# Processing file 49/2048: design8_n49.pdb
# Processing file 50/2048: design14_n5.pdb
# Processing file 51/2048: design24_n48.pdb
# Processing file 52/2048: design13_n36.pdb
# Processing file 53/2048: design0_n19.pdb
# Processing file 54/2048: design14_n3.pdb
# Processing file 55/2048: design27_n2.pdb
# Processing file 56/2048: design27_n21.pdb
# Processing file 57/2048: design12_n62.pdb
# Processing file 58/2048: design9_n26.pdb
# Processing file 59/2048: design22_n54.pdb
# Processing file 60/2048: design16_n25.pdb
# Processing file 61/2048: design3_n30.pdb
# Processing file 62/2048: design24_n49.pdb
# Processing file 63/2048: design23_n12.pdb
# Processing file 64/2048: design22_n35.pdb
# Processing file 65/2048: design19_n22.pdb
# Processing file 66/2048: design8_n53.pdb
# Processing file 67/2048: design20_n44.pdb
# Processing file 68/2048: design0_n28.pdb
# Processing file 69/2048: design4_n8.pdb
# Processing file 70/2048: design23_n58.pdb
# Processing file 71/2048: design7_n21.pdb
# Processing file 72/2048: design7_n54.pdb
# Processing file 73/2048: design9_n12.pdb
# Processing file 74/2048: design15_n25.pdb
# Processing file 75/2048: design15_n8.pdb
# Processing file 76/2048: design18_n16.pdb
# Processing file 77/2048: design7_n34.pdb
# Processing file 78/2048: design29_n5.pdb
# Processing file 79/2048: design27_n7.pdb
# Processing file 80/2048: design8_n43.pdb
# Processing file 81/2048: design12_n48.pdb
# Processing file 82/2048: design3_n51.pdb
# Processing file 83/2048: design2_n8.pdb
# Processing file 84/2048: design0_n60.pdb
# Processing file 85/2048: design5_n61.pdb
# Processing file 86/2048: design22_n6.pdb
# Processing file 87/2048: design4_n59.pdb
# Processing file 88/2048: design8_n33.pdb
# Processing file 89/2048: design0_n23.pdb
# Processing file 90/2048: design8_n19.pdb
# Processing file 91/2048: design9_n46.pdb
# Processing file 92/2048: design26_n61.pdb
# Processing file 93/2048: design10_n63.pdb
# Processing file 94/2048: design9_n24.pdb
# Processing file 95/2048: design1_n13.pdb
# Processing file 96/2048: design24_n20.pdb
# Processing file 97/2048: design24_n31.pdb
# Processing file 98/2048: design4_n30.pdb
# Processing file 99/2048: design24_n24.pdb
# Processing file 100/2048: design29_n34.pdb
# Processing file 101/2048: design20_n21.pdb
# Processing file 102/2048: design29_n32.pdb
# Processing file 103/2048: design6_n22.pdb
# Processing file 104/2048: design16_n58.pdb
# Processing file 105/2048: design11_n22.pdb
# Processing file 106/2048: design10_n38.pdb
# Processing file 107/2048: design1_n5.pdb
# Processing file 108/2048: design17_n24.pdb
# Processing file 109/2048: design25_n4.pdb
# Processing file 110/2048: design10_n18.pdb
# Processing file 111/2048: design18_n11.pdb
# Processing file 112/2048: design9_n52.pdb
# Processing file 113/2048: design8_n61.pdb
# Processing file 114/2048: design24_n40.pdb
# Processing file 115/2048: design26_n52.pdb
# Processing file 116/2048: design0_n63.pdb
# Processing file 117/2048: design16_n36.pdb
# Processing file 118/2048: design20_n5.pdb
# Processing file 119/2048: design15_n9.pdb
# Processing file 120/2048: design21_n53.pdb
# Processing file 121/2048: design4_n13.pdb
# Processing file 122/2048: design25_n29.pdb
# Processing file 123/2048: design29_n61.pdb
# Processing file 124/2048: design18_n29.pdb
# Processing file 125/2048: design7_n22.pdb
# Processing file 126/2048: design11_n23.pdb
# Processing file 127/2048: design23_n24.pdb
# Processing file 128/2048: design14_n57.pdb
# Processing file 129/2048: design24_n56.pdb
# Processing file 130/2048: design25_n10.pdb
# Processing file 131/2048: design4_n11.pdb
# Processing file 132/2048: design14_n63.pdb
# Processing file 133/2048: design15_n14.pdb
# Processing file 134/2048: design19_n48.pdb
# Processing file 135/2048: design19_n2.pdb
# Processing file 136/2048: design30_n18.pdb
# Processing file 137/2048: design28_n13.pdb
# Processing file 138/2048: design23_n51.pdb
# Processing file 139/2048: design2_n55.pdb
# Processing file 140/2048: design9_n19.pdb
# Processing file 141/2048: design18_n19.pdb
# Processing file 142/2048: design25_n54.pdb
# Processing file 143/2048: design24_n45.pdb
# Processing file 144/2048: design6_n27.pdb
# Processing file 145/2048: design31_n4.pdb
# Processing file 146/2048: design14_n58.pdb
# Processing file 147/2048: design22_n1.pdb
# Processing file 148/2048: design29_n20.pdb
# Processing file 149/2048: design2_n13.pdb
# Processing file 150/2048: design9_n47.pdb
# Processing file 151/2048: design23_n49.pdb
# Processing file 152/2048: design21_n46.pdb
# Processing file 153/2048: design29_n51.pdb
# Processing file 154/2048: design25_n34.pdb
# Processing file 155/2048: design2_n17.pdb
# Processing file 156/2048: design21_n43.pdb
# Processing file 157/2048: design23_n30.pdb
# Processing file 158/2048: design8_n25.pdb
# Processing file 159/2048: design29_n11.pdb
# Processing file 160/2048: design30_n52.pdb
# Processing file 161/2048: design5_n5.pdb
# Processing file 162/2048: design23_n45.pdb
# Processing file 163/2048: design2_n63.pdb
# Processing file 164/2048: design25_n60.pdb
# Processing file 165/2048: design11_n47.pdb
# Processing file 166/2048: design27_n25.pdb
# Processing file 167/2048: design24_n3.pdb
# Processing file 168/2048: design20_n18.pdb
# Processing file 169/2048: design6_n2.pdb
# Processing file 170/2048: design31_n38.pdb
# Processing file 171/2048: design17_n8.pdb
# Processing file 172/2048: design7_n44.pdb
# Processing file 173/2048: design18_n63.pdb
# Processing file 174/2048: design4_n4.pdb
# Processing file 175/2048: design27_n1.pdb
# Processing file 176/2048: design11_n5.pdb
# Processing file 177/2048: design18_n40.pdb
# Processing file 178/2048: design9_n29.pdb
# Processing file 179/2048: design27_n35.pdb
# Processing file 180/2048: design9_n15.pdb
# Processing file 181/2048: design28_n18.pdb
# Processing file 182/2048: design26_n62.pdb
# Processing file 183/2048: design8_n35.pdb
# Processing file 184/2048: design3_n59.pdb
# Processing file 185/2048: design2_n61.pdb
# Processing file 186/2048: design27_n39.pdb
# Processing file 187/2048: design20_n26.pdb
# Processing file 188/2048: design4_n54.pdb
# Processing file 189/2048: design3_n25.pdb
# Processing file 190/2048: design11_n50.pdb
# Processing file 191/2048: design4_n17.pdb
# Processing file 192/2048: design6_n53.pdb
# Processing file 193/2048: design28_n60.pdb
# Processing file 194/2048: design0_n21.pdb
# Processing file 195/2048: design23_n17.pdb
# Processing file 196/2048: design23_n20.pdb
# Processing file 197/2048: design3_n8.pdb
# Processing file 198/2048: design29_n39.pdb
# Processing file 199/2048: design22_n27.pdb
# Processing file 200/2048: design14_n49.pdb
# Processing file 201/2048: design21_n13.pdb
# Processing file 202/2048: design13_n7.pdb
# Processing file 203/2048: design18_n17.pdb
# Processing file 204/2048: design14_n27.pdb
# Processing file 205/2048: design24_n37.pdb
# Processing file 206/2048: design19_n3.pdb
# Processing file 207/2048: design20_n4.pdb
# Processing file 208/2048: design11_n12.pdb
# Processing file 209/2048: design26_n48.pdb
# Processing file 210/2048: design25_n11.pdb
# Processing file 211/2048: design31_n35.pdb
# Processing file 212/2048: design17_n5.pdb
# Processing file 213/2048: design1_n36.pdb
# Processing file 214/2048: design13_n56.pdb
# Processing file 215/2048: design29_n1.pdb
# Processing file 216/2048: design30_n10.pdb
# Processing file 217/2048: design7_n14.pdb
# Processing file 218/2048: design11_n20.pdb
# Processing file 219/2048: design7_n12.pdb
# Processing file 220/2048: design15_n38.pdb
# Processing file 221/2048: design28_n41.pdb
# Processing file 222/2048: design22_n3.pdb
# Processing file 223/2048: design20_n32.pdb
# Processing file 224/2048: design5_n15.pdb
# Processing file 225/2048: design1_n40.pdb
# Processing file 226/2048: design20_n63.pdb
# Processing file 227/2048: design24_n15.pdb
# Processing file 228/2048: design6_n49.pdb
# Processing file 229/2048: design11_n34.pdb
# Processing file 230/2048: design14_n8.pdb
# Processing file 231/2048: design19_n52.pdb
# Processing file 232/2048: design23_n16.pdb
# Processing file 233/2048: design13_n28.pdb
# Processing file 234/2048: design17_n36.pdb
# Processing file 235/2048: design25_n18.pdb
# Processing file 236/2048: design5_n58.pdb
# Processing file 237/2048: design23_n1.pdb
# Processing file 238/2048: design17_n50.pdb
# Processing file 239/2048: design11_n55.pdb
# Processing file 240/2048: design26_n13.pdb
# Processing file 241/2048: design1_n37.pdb
# Processing file 242/2048: design16_n48.pdb
# Processing file 243/2048: design18_n48.pdb
# Processing file 244/2048: design11_n59.pdb
# Processing file 245/2048: design19_n17.pdb
# Processing file 246/2048: design8_n12.pdb
# Processing file 247/2048: design31_n48.pdb
# Processing file 248/2048: design11_n48.pdb
# Processing file 249/2048: design6_n47.pdb
# Processing file 250/2048: design10_n39.pdb
# Processing file 251/2048: design6_n15.pdb
# Processing file 252/2048: design0_n34.pdb
# Processing file 253/2048: design26_n39.pdb
# Processing file 254/2048: design12_n53.pdb
# Processing file 255/2048: design18_n33.pdb
# Processing file 256/2048: design27_n51.pdb
# Processing file 257/2048: design19_n34.pdb
# Processing file 258/2048: design1_n3.pdb
# Processing file 259/2048: design12_n20.pdb
# Processing file 260/2048: design18_n52.pdb
# Processing file 261/2048: design21_n6.pdb
# Processing file 262/2048: design18_n20.pdb
# Processing file 263/2048: design5_n40.pdb
# Processing file 264/2048: design26_n44.pdb
# Processing file 265/2048: design29_n57.pdb
# Processing file 266/2048: design13_n20.pdb
# Processing file 267/2048: design4_n9.pdb
# Processing file 268/2048: design13_n34.pdb
# Processing file 269/2048: design31_n43.pdb
# Processing file 270/2048: design24_n52.pdb
# Processing file 271/2048: design23_n11.pdb
# Processing file 272/2048: design3_n53.pdb
# Processing file 273/2048: design1_n0.pdb
# Processing file 274/2048: design17_n29.pdb
# Processing file 275/2048: design1_n35.pdb
# Processing file 276/2048: design26_n58.pdb
# Processing file 277/2048: design12_n51.pdb
# Processing file 278/2048: design17_n13.pdb
# Processing file 279/2048: design15_n56.pdb
# Processing file 280/2048: design15_n23.pdb
# Processing file 281/2048: design15_n57.pdb
# Processing file 282/2048: design19_n36.pdb
# Processing file 283/2048: design26_n11.pdb
# Processing file 284/2048: design8_n15.pdb
# Processing file 285/2048: design0_n33.pdb
# Processing file 286/2048: design1_n62.pdb
# Processing file 287/2048: design1_n27.pdb
# Processing file 288/2048: design20_n38.pdb
# Processing file 289/2048: design10_n58.pdb
# Processing file 290/2048: design10_n17.pdb
# Processing file 291/2048: design2_n7.pdb
# Processing file 292/2048: design16_n52.pdb
# Processing file 293/2048: design24_n0.pdb
# Processing file 294/2048: design27_n52.pdb
# Processing file 295/2048: design6_n7.pdb
# Processing file 296/2048: design23_n8.pdb
# Processing file 297/2048: design11_n45.pdb
# Processing file 298/2048: design20_n56.pdb
# Processing file 299/2048: design28_n12.pdb
# Processing file 300/2048: design21_n58.pdb
# Processing file 301/2048: design1_n23.pdb
# Processing file 302/2048: design12_n36.pdb
# Processing file 303/2048: design27_n55.pdb
# Processing file 304/2048: design23_n18.pdb
# Processing file 305/2048: design17_n3.pdb
# Processing file 306/2048: design17_n33.pdb
# Processing file 307/2048: design0_n12.pdb
# Processing file 308/2048: design28_n17.pdb
# Processing file 309/2048: design13_n8.pdb
# Processing file 310/2048: design17_n12.pdb
# Processing file 311/2048: design14_n11.pdb
# Processing file 312/2048: design26_n34.pdb
# Processing file 313/2048: design30_n59.pdb
# Processing file 314/2048: design26_n51.pdb
# Processing file 315/2048: design14_n53.pdb
# Processing file 316/2048: design13_n16.pdb
# Processing file 317/2048: design5_n37.pdb
# Processing file 318/2048: design29_n4.pdb
# Processing file 319/2048: design15_n52.pdb
# Processing file 320/2048: design15_n54.pdb
# Processing file 321/2048: design12_n41.pdb
# Processing file 322/2048: design30_n22.pdb
# Processing file 323/2048: design25_n28.pdb
# Processing file 324/2048: design8_n50.pdb
# Processing file 325/2048: design15_n55.pdb
# Processing file 326/2048: design19_n60.pdb
# Processing file 327/2048: design0_n22.pdb
# Processing file 328/2048: design5_n49.pdb
# Processing file 329/2048: design16_n46.pdb
# Processing file 330/2048: design6_n11.pdb
# Processing file 331/2048: design21_n2.pdb
# Processing file 332/2048: design29_n26.pdb
# Processing file 333/2048: design19_n39.pdb
# Processing file 334/2048: design3_n33.pdb
# Processing file 335/2048: design24_n5.pdb
# Processing file 336/2048: design28_n53.pdb
# Processing file 337/2048: design22_n47.pdb
# Processing file 338/2048: design13_n4.pdb
# Processing file 339/2048: design0_n48.pdb
# Processing file 340/2048: design2_n30.pdb
# Processing file 341/2048: design29_n17.pdb
# Processing file 342/2048: design18_n46.pdb
# Processing file 343/2048: design6_n62.pdb
# Processing file 344/2048: design6_n39.pdb
# Processing file 345/2048: design8_n62.pdb
# Processing file 346/2048: design29_n43.pdb
# Processing file 347/2048: design9_n35.pdb
# Processing file 348/2048: design27_n18.pdb
# Processing file 349/2048: design5_n22.pdb
# Processing file 350/2048: design9_n57.pdb
# Processing file 351/2048: design3_n21.pdb
# Processing file 352/2048: design9_n62.pdb
# Processing file 353/2048: design26_n2.pdb
# Processing file 354/2048: design24_n54.pdb
# Processing file 355/2048: design10_n37.pdb
# Processing file 356/2048: design24_n26.pdb
# Processing file 357/2048: design5_n4.pdb
# Processing file 358/2048: design12_n32.pdb
# Processing file 359/2048: design10_n33.pdb
# Processing file 360/2048: design15_n37.pdb
# Processing file 361/2048: design6_n60.pdb
# Processing file 362/2048: design9_n20.pdb
# Processing file 363/2048: design22_n57.pdb
# Processing file 364/2048: design7_n62.pdb
# Processing file 365/2048: design12_n47.pdb
# Processing file 366/2048: design1_n55.pdb
# Processing file 367/2048: design3_n54.pdb
# Processing file 368/2048: design27_n6.pdb
# Processing file 369/2048: design6_n54.pdb
# Processing file 370/2048: design4_n21.pdb
# Processing file 371/2048: design19_n55.pdb
# Processing file 372/2048: design7_n53.pdb
# Processing file 373/2048: design3_n60.pdb
# Processing file 374/2048: design31_n15.pdb
# Processing file 375/2048: design1_n11.pdb
# Processing file 376/2048: design8_n57.pdb
# Processing file 377/2048: design6_n5.pdb
# Processing file 378/2048: design10_n16.pdb
# Processing file 379/2048: design20_n30.pdb
# Processing file 380/2048: design0_n10.pdb
# Processing file 381/2048: design4_n19.pdb
# Processing file 382/2048: design21_n34.pdb
# Processing file 383/2048: design9_n30.pdb
# Processing file 384/2048: design26_n15.pdb
# Processing file 385/2048: design9_n36.pdb
# Processing file 386/2048: design5_n9.pdb
# Processing file 387/2048: design14_n61.pdb
# Processing file 388/2048: design30_n26.pdb
# Processing file 389/2048: design23_n2.pdb
# Processing file 390/2048: design3_n15.pdb
# Processing file 391/2048: design18_n37.pdb
# Processing file 392/2048: design2_n38.pdb
# Processing file 393/2048: design26_n50.pdb
# Processing file 394/2048: design1_n45.pdb
# Processing file 395/2048: design22_n46.pdb
# Processing file 396/2048: design17_n15.pdb
# Processing file 397/2048: design1_n28.pdb
# Processing file 398/2048: design11_n35.pdb
# Processing file 399/2048: design4_n41.pdb
# Processing file 400/2048: design28_n24.pdb
# Processing file 401/2048: design2_n11.pdb
# Processing file 402/2048: design3_n50.pdb
# Processing file 403/2048: design10_n3.pdb
# Processing file 404/2048: design14_n22.pdb
# Processing file 405/2048: design0_n0.pdb
# Processing file 406/2048: design2_n42.pdb
# Processing file 407/2048: design6_n29.pdb
# Processing file 408/2048: design2_n23.pdb
# Processing file 409/2048: design1_n34.pdb
# Processing file 410/2048: design10_n25.pdb
# Processing file 411/2048: design22_n24.pdb
# Processing file 412/2048: design31_n44.pdb
# Processing file 413/2048: design16_n0.pdb
# Processing file 414/2048: design24_n2.pdb
# Processing file 415/2048: design2_n25.pdb
# Processing file 416/2048: design3_n31.pdb
# Processing file 417/2048: design3_n41.pdb
# Processing file 418/2048: design26_n31.pdb
# Processing file 419/2048: design10_n55.pdb
# Processing file 420/2048: design26_n42.pdb
# Processing file 421/2048: design4_n5.pdb
# Processing file 422/2048: design28_n16.pdb
# Processing file 423/2048: design28_n61.pdb
# Processing file 424/2048: design11_n10.pdb
# Processing file 425/2048: design2_n40.pdb
# Processing file 426/2048: design14_n42.pdb
# Processing file 427/2048: design7_n30.pdb
# Processing file 428/2048: design23_n60.pdb
# Processing file 429/2048: design25_n51.pdb
# Processing file 430/2048: design7_n35.pdb
# Processing file 431/2048: design15_n27.pdb
# Processing file 432/2048: design17_n61.pdb
# Processing file 433/2048: design22_n51.pdb
# Processing file 434/2048: design23_n50.pdb
# Processing file 435/2048: design16_n41.pdb
# Processing file 436/2048: design9_n11.pdb
# Processing file 437/2048: design9_n51.pdb
# Processing file 438/2048: design3_n35.pdb
# Processing file 439/2048: design0_n5.pdb
# Processing file 440/2048: design10_n4.pdb
# Processing file 441/2048: design4_n53.pdb
# Processing file 442/2048: design6_n4.pdb
# Processing file 443/2048: design13_n47.pdb
# Processing file 444/2048: design13_n50.pdb
# Processing file 445/2048: design3_n4.pdb
# Processing file 446/2048: design20_n47.pdb
# Processing file 447/2048: design26_n29.pdb
# Processing file 448/2048: design0_n32.pdb
# Processing file 449/2048: design28_n51.pdb
# Processing file 450/2048: design9_n23.pdb
# Processing file 451/2048: design28_n54.pdb
# Processing file 452/2048: design26_n23.pdb
# Processing file 453/2048: design23_n5.pdb
# Processing file 454/2048: design5_n6.pdb
# Processing file 455/2048: design5_n11.pdb
# Processing file 456/2048: design13_n54.pdb
# Processing file 457/2048: design19_n37.pdb
# Processing file 458/2048: design31_n52.pdb
# Processing file 459/2048: design6_n17.pdb
# Processing file 460/2048: design5_n17.pdb
# Processing file 461/2048: design5_n56.pdb
# Processing file 462/2048: design11_n41.pdb
# Processing file 463/2048: design26_n33.pdb
# Processing file 464/2048: design14_n18.pdb
# Processing file 465/2048: design11_n51.pdb
# Processing file 466/2048: design14_n34.pdb
# Processing file 467/2048: design19_n29.pdb
# Processing file 468/2048: design12_n23.pdb
# Processing file 469/2048: design31_n34.pdb
# Processing file 470/2048: design28_n39.pdb
# Processing file 471/2048: design29_n2.pdb
# Processing file 472/2048: design9_n1.pdb
# Processing file 473/2048: design29_n45.pdb
# Processing file 474/2048: design27_n32.pdb
# Processing file 475/2048: design20_n22.pdb
# Processing file 476/2048: design3_n34.pdb
# Processing file 477/2048: design5_n24.pdb
# Processing file 478/2048: design23_n55.pdb
# Processing file 479/2048: design11_n43.pdb
# Processing file 480/2048: design19_n23.pdb
# Processing file 481/2048: design10_n12.pdb
# Processing file 482/2048: design22_n22.pdb
# Processing file 483/2048: design30_n1.pdb
# Processing file 484/2048: design12_n54.pdb
# Processing file 485/2048: design11_n40.pdb
# Processing file 486/2048: design18_n3.pdb
# Processing file 487/2048: design13_n32.pdb
# Processing file 488/2048: design30_n3.pdb
# Processing file 489/2048: design4_n43.pdb
# Processing file 490/2048: design24_n14.pdb
# Processing file 491/2048: design8_n18.pdb
# Processing file 492/2048: design28_n59.pdb
# Processing file 493/2048: design21_n10.pdb
# Processing file 494/2048: design25_n36.pdb
# Processing file 495/2048: design19_n49.pdb
# Processing file 496/2048: design4_n29.pdb
# Processing file 497/2048: design11_n26.pdb
# Processing file 498/2048: design15_n36.pdb
# Processing file 499/2048: design26_n40.pdb
# Processing file 500/2048: design28_n19.pdb
# Processing file 501/2048: design5_n59.pdb
# Processing file 502/2048: design15_n30.pdb
# Processing file 503/2048: design8_n26.pdb
# Processing file 504/2048: design2_n41.pdb
# Processing file 505/2048: design28_n27.pdb
# Processing file 506/2048: design9_n53.pdb
# Processing file 507/2048: design7_n39.pdb
# Processing file 508/2048: design30_n48.pdb
# Processing file 509/2048: design3_n2.pdb
# Processing file 510/2048: design23_n48.pdb
# Processing file 511/2048: design0_n1.pdb
# Processing file 512/2048: design30_n20.pdb
# Processing file 513/2048: design6_n30.pdb
# Processing file 514/2048: design21_n1.pdb
# Processing file 515/2048: design11_n9.pdb
# Processing file 516/2048: design9_n33.pdb
# Processing file 517/2048: design24_n23.pdb
# Processing file 518/2048: design25_n5.pdb
# Processing file 519/2048: design30_n38.pdb
# Processing file 520/2048: design28_n15.pdb
# Processing file 521/2048: design6_n55.pdb
# Processing file 522/2048: design9_n55.pdb
# Processing file 523/2048: design11_n56.pdb
# Processing file 524/2048: design25_n12.pdb
# Processing file 525/2048: design6_n19.pdb
# Processing file 526/2048: design30_n37.pdb
# Processing file 527/2048: design4_n20.pdb
# Processing file 528/2048: design12_n15.pdb
# Processing file 529/2048: design8_n10.pdb
# Processing file 530/2048: design8_n59.pdb
# Processing file 531/2048: design11_n28.pdb
# Processing file 532/2048: design28_n55.pdb
# Processing file 533/2048: design28_n52.pdb
# Processing file 534/2048: design10_n57.pdb
# Processing file 535/2048: design1_n22.pdb
# Processing file 536/2048: design30_n17.pdb
# Processing file 537/2048: design12_n57.pdb
# Processing file 538/2048: design26_n49.pdb
# Processing file 539/2048: design11_n29.pdb
# Processing file 540/2048: design18_n58.pdb
# Processing file 541/2048: design27_n47.pdb
# Processing file 542/2048: design27_n17.pdb
# Processing file 543/2048: design16_n21.pdb
# Processing file 544/2048: design9_n60.pdb
# Processing file 545/2048: design28_n31.pdb
# Processing file 546/2048: design28_n3.pdb
# Processing file 547/2048: design16_n61.pdb
# Processing file 548/2048: design25_n53.pdb
# Processing file 549/2048: design30_n36.pdb
# Processing file 550/2048: design9_n21.pdb
# Processing file 551/2048: design0_n42.pdb
# Processing file 552/2048: design23_n22.pdb
# Processing file 553/2048: design27_n56.pdb
# Processing file 554/2048: design30_n50.pdb
# Processing file 555/2048: design22_n20.pdb
# Processing file 556/2048: design31_n58.pdb
# Processing file 557/2048: design5_n25.pdb
# Processing file 558/2048: design31_n29.pdb
# Processing file 559/2048: design13_n15.pdb
# Processing file 560/2048: design25_n59.pdb
# Processing file 561/2048: design27_n41.pdb
# Processing file 562/2048: design6_n33.pdb
# Processing file 563/2048: design21_n11.pdb
# Processing file 564/2048: design19_n57.pdb
# Processing file 565/2048: design27_n62.pdb
# Processing file 566/2048: design28_n10.pdb
# Processing file 567/2048: design26_n47.pdb
# Processing file 568/2048: design25_n8.pdb
# Processing file 569/2048: design18_n23.pdb
# Processing file 570/2048: design7_n60.pdb
# Processing file 571/2048: design7_n6.pdb
# Processing file 572/2048: design25_n49.pdb
# Processing file 573/2048: design16_n59.pdb
# Processing file 574/2048: design25_n39.pdb
# Processing file 575/2048: design10_n32.pdb
# Processing file 576/2048: design18_n6.pdb
# Processing file 577/2048: design1_n1.pdb
# Processing file 578/2048: design31_n1.pdb
# Processing file 579/2048: design8_n24.pdb
# Processing file 580/2048: design25_n13.pdb
# Processing file 581/2048: design3_n52.pdb
# Processing file 582/2048: design9_n45.pdb
# Processing file 583/2048: design4_n36.pdb
# Processing file 584/2048: design4_n39.pdb
# Processing file 585/2048: design25_n50.pdb
# Processing file 586/2048: design26_n9.pdb
# Processing file 587/2048: design25_n1.pdb
# Processing file 588/2048: design2_n6.pdb
# Processing file 589/2048: design9_n18.pdb
# Processing file 590/2048: design25_n2.pdb
# Processing file 591/2048: design12_n7.pdb
# Processing file 592/2048: design2_n36.pdb
# Processing file 593/2048: design14_n45.pdb
# Processing file 594/2048: design19_n58.pdb
# Processing file 595/2048: design6_n31.pdb
# Processing file 596/2048: design1_n49.pdb
# Processing file 597/2048: design31_n13.pdb
# Processing file 598/2048: design24_n19.pdb
# Processing file 599/2048: design31_n61.pdb
# Processing file 600/2048: design21_n15.pdb
# Processing file 601/2048: design16_n12.pdb
# Processing file 602/2048: design24_n51.pdb
# Processing file 603/2048: design13_n42.pdb
# Processing file 604/2048: design27_n0.pdb
# Processing file 605/2048: design20_n31.pdb
# Processing file 606/2048: design27_n22.pdb
# Processing file 607/2048: design19_n41.pdb
# Processing file 608/2048: design21_n24.pdb
# Processing file 609/2048: design5_n44.pdb
# Processing file 610/2048: design8_n0.pdb
# Processing file 611/2048: design20_n23.pdb
# Processing file 612/2048: design29_n19.pdb
# Processing file 613/2048: design10_n2.pdb
# Processing file 614/2048: design12_n18.pdb
# Processing file 615/2048: design18_n2.pdb
# Processing file 616/2048: design31_n30.pdb
# Processing file 617/2048: design4_n50.pdb
# Processing file 618/2048: design28_n30.pdb
# Processing file 619/2048: design25_n47.pdb
# Processing file 620/2048: design25_n33.pdb
# Processing file 621/2048: design1_n39.pdb
# Processing file 622/2048: design2_n12.pdb
# Processing file 623/2048: design0_n47.pdb
# Processing file 624/2048: design12_n12.pdb
# Processing file 625/2048: design31_n32.pdb
# Processing file 626/2048: design20_n12.pdb
# Processing file 627/2048: design30_n2.pdb
# Processing file 628/2048: design11_n24.pdb
# Processing file 629/2048: design2_n35.pdb
# Processing file 630/2048: design14_n60.pdb
# Processing file 631/2048: design23_n53.pdb
# Processing file 632/2048: design31_n8.pdb
# Processing file 633/2048: design23_n31.pdb
# Processing file 634/2048: design10_n6.pdb
# Processing file 635/2048: design6_n52.pdb
# Processing file 636/2048: design12_n26.pdb
# Processing file 637/2048: design18_n12.pdb
# Processing file 638/2048: design17_n14.pdb
# Processing file 639/2048: design22_n48.pdb
# Processing file 640/2048: design20_n40.pdb
# Processing file 641/2048: design4_n35.pdb
# Processing file 642/2048: design23_n36.pdb
# Processing file 643/2048: design31_n63.pdb
# Processing file 644/2048: design27_n14.pdb
# Processing file 645/2048: design3_n48.pdb
# Processing file 646/2048: design30_n35.pdb
# Processing file 647/2048: design16_n20.pdb
# Processing file 648/2048: design27_n12.pdb
# Processing file 649/2048: design27_n53.pdb
# Processing file 650/2048: design23_n21.pdb
# Processing file 651/2048: design1_n2.pdb
# Processing file 652/2048: design29_n33.pdb
# Processing file 653/2048: design10_n61.pdb
# Processing file 654/2048: design11_n38.pdb
# Processing file 655/2048: design18_n45.pdb
# Processing file 656/2048: design15_n20.pdb
# Processing file 657/2048: design14_n36.pdb
# Processing file 658/2048: design18_n51.pdb
# Processing file 659/2048: design29_n40.pdb
# Processing file 660/2048: design4_n3.pdb
# Processing file 661/2048: design19_n50.pdb
# Processing file 662/2048: design30_n11.pdb
# Processing file 663/2048: design13_n12.pdb
# Processing file 664/2048: design21_n5.pdb
# Processing file 665/2048: design7_n36.pdb
# Processing file 666/2048: design13_n30.pdb
# Processing file 667/2048: design9_n56.pdb
# Processing file 668/2048: design6_n51.pdb
# Processing file 669/2048: design10_n41.pdb
# Processing file 670/2048: design2_n53.pdb
# Processing file 671/2048: design21_n48.pdb
# Processing file 672/2048: design20_n14.pdb
# Processing file 673/2048: design30_n15.pdb
# Processing file 674/2048: design4_n32.pdb
# Processing file 675/2048: design2_n9.pdb
# Processing file 676/2048: design20_n28.pdb
# Processing file 677/2048: design17_n56.pdb
# Processing file 678/2048: design11_n46.pdb
# Processing file 679/2048: design7_n28.pdb
# Processing file 680/2048: design22_n0.pdb
# Processing file 681/2048: design24_n33.pdb
# Processing file 682/2048: design29_n35.pdb
# Processing file 683/2048: design30_n5.pdb
# Processing file 684/2048: design6_n20.pdb
# Processing file 685/2048: design27_n10.pdb
# Processing file 686/2048: design9_n28.pdb
# Processing file 687/2048: design7_n24.pdb
# Processing file 688/2048: design16_n22.pdb
# Processing file 689/2048: design29_n6.pdb
# Processing file 690/2048: design22_n4.pdb
# Processing file 691/2048: design4_n14.pdb
# Processing file 692/2048: design17_n63.pdb
# Processing file 693/2048: design18_n59.pdb
# Processing file 694/2048: design30_n19.pdb
# Processing file 695/2048: design21_n27.pdb
# Processing file 696/2048: design29_n12.pdb
# Processing file 697/2048: design25_n58.pdb
# Processing file 698/2048: design17_n53.pdb
# Processing file 699/2048: design10_n9.pdb
# Processing file 700/2048: design7_n61.pdb
# Processing file 701/2048: design1_n50.pdb
# Processing file 702/2048: design8_n21.pdb
# Processing file 703/2048: design2_n10.pdb
# Processing file 704/2048: design13_n41.pdb
# Processing file 705/2048: design7_n50.pdb
# Processing file 706/2048: design12_n1.pdb
# Processing file 707/2048: design14_n7.pdb
# Processing file 708/2048: design11_n37.pdb
# Processing file 709/2048: design11_n18.pdb
# Processing file 710/2048: design21_n56.pdb
# Processing file 711/2048: design11_n60.pdb
# Processing file 712/2048: design13_n24.pdb
# Processing file 713/2048: design31_n56.pdb
# Processing file 714/2048: design28_n56.pdb
# Processing file 715/2048: design16_n35.pdb
# Processing file 716/2048: design27_n8.pdb
# Processing file 717/2048: design8_n1.pdb
# Processing file 718/2048: design1_n26.pdb
# Processing file 719/2048: design29_n62.pdb
# Processing file 720/2048: design9_n8.pdb
# Processing file 721/2048: design16_n32.pdb
# Processing file 722/2048: design13_n53.pdb
# Processing file 723/2048: design13_n22.pdb
# Processing file 724/2048: design13_n45.pdb
# Processing file 725/2048: design13_n35.pdb
# Processing file 726/2048: design27_n57.pdb
# Processing file 727/2048: design26_n8.pdb
# Processing file 728/2048: design3_n19.pdb
# Processing file 729/2048: design7_n55.pdb
# Processing file 730/2048: design2_n62.pdb
# Processing file 731/2048: design31_n9.pdb
# Processing file 732/2048: design4_n18.pdb
# Processing file 733/2048: design7_n11.pdb
# Processing file 734/2048: design9_n34.pdb
# Processing file 735/2048: design0_n50.pdb
# Processing file 736/2048: design6_n26.pdb
# Processing file 737/2048: design17_n6.pdb
# Processing file 738/2048: design6_n24.pdb
# Processing file 739/2048: design27_n4.pdb
# Processing file 740/2048: design21_n25.pdb
# Processing file 741/2048: design22_n9.pdb
# Processing file 742/2048: design15_n49.pdb
# Processing file 743/2048: design14_n24.pdb
# Processing file 744/2048: design10_n43.pdb
# Processing file 745/2048: design19_n15.pdb
# Processing file 746/2048: design10_n53.pdb
# Processing file 747/2048: design2_n3.pdb
# Processing file 748/2048: design20_n20.pdb
# Processing file 749/2048: design10_n40.pdb
# Processing file 750/2048: design12_n44.pdb
# Processing file 751/2048: design27_n38.pdb
# Processing file 752/2048: design23_n25.pdb
# Processing file 753/2048: design12_n33.pdb
# Processing file 754/2048: design22_n61.pdb
# Processing file 755/2048: design9_n22.pdb
# Processing file 756/2048: design0_n53.pdb
# Processing file 757/2048: design30_n43.pdb
# Processing file 758/2048: design3_n20.pdb
# Processing file 759/2048: design20_n15.pdb
# Processing file 760/2048: design2_n60.pdb
# Processing file 761/2048: design10_n31.pdb
# Processing file 762/2048: design10_n1.pdb
# Processing file 763/2048: design21_n47.pdb
# Processing file 764/2048: design26_n6.pdb
# Processing file 765/2048: design0_n16.pdb
# Processing file 766/2048: design17_n30.pdb
# Processing file 767/2048: design22_n17.pdb
# Processing file 768/2048: design20_n54.pdb
# Processing file 769/2048: design1_n25.pdb
# Processing file 770/2048: design11_n62.pdb
# Processing file 771/2048: design29_n15.pdb
# Processing file 772/2048: design23_n46.pdb
# Processing file 773/2048: design16_n29.pdb
# Processing file 774/2048: design3_n13.pdb
# Processing file 775/2048: design2_n50.pdb
# Processing file 776/2048: design27_n33.pdb
# Processing file 777/2048: design22_n32.pdb
# Processing file 778/2048: design1_n29.pdb
# Processing file 779/2048: design7_n45.pdb
# Processing file 780/2048: design26_n46.pdb
# Processing file 781/2048: design9_n2.pdb
# Processing file 782/2048: design20_n3.pdb
# Processing file 783/2048: design21_n60.pdb
# Processing file 784/2048: design15_n35.pdb
# Processing file 785/2048: design25_n32.pdb
# Processing file 786/2048: design11_n13.pdb
# Processing file 787/2048: design15_n29.pdb
# Processing file 788/2048: design25_n30.pdb
# Processing file 789/2048: design4_n0.pdb
# Processing file 790/2048: design17_n22.pdb
# Processing file 791/2048: design25_n16.pdb
# Processing file 792/2048: design1_n32.pdb
# Processing file 793/2048: design7_n27.pdb
# Processing file 794/2048: design30_n4.pdb
# Processing file 795/2048: design21_n0.pdb
# Processing file 796/2048: design3_n6.pdb
# Processing file 797/2048: design17_n1.pdb
# Processing file 798/2048: design16_n39.pdb
# Processing file 799/2048: design26_n19.pdb
# Processing file 800/2048: design28_n34.pdb
# Processing file 801/2048: design29_n23.pdb
# Processing file 802/2048: design10_n19.pdb
# Processing file 803/2048: design23_n47.pdb
# Processing file 804/2048: design16_n62.pdb
# Processing file 805/2048: design15_n59.pdb
# Processing file 806/2048: design29_n55.pdb
# Processing file 807/2048: design8_n31.pdb
# Processing file 808/2048: design7_n41.pdb
# Processing file 809/2048: design31_n49.pdb
# Processing file 810/2048: design0_n35.pdb
# Processing file 811/2048: design21_n35.pdb
# Processing file 812/2048: design10_n0.pdb
# Processing file 813/2048: design21_n49.pdb
# Processing file 814/2048: design23_n62.pdb
# Processing file 815/2048: design4_n49.pdb
# Processing file 816/2048: design16_n33.pdb
# Processing file 817/2048: design0_n36.pdb
# Processing file 818/2048: design9_n31.pdb
# Processing file 819/2048: design30_n7.pdb
# Processing file 820/2048: design23_n63.pdb
# Processing file 821/2048: design30_n47.pdb
# Processing file 822/2048: design10_n10.pdb
# Processing file 823/2048: design1_n14.pdb
# Processing file 824/2048: design22_n7.pdb
# Processing file 825/2048: design24_n4.pdb
# Processing file 826/2048: design6_n10.pdb
# Processing file 827/2048: design14_n10.pdb
# Processing file 828/2048: design16_n54.pdb
# Processing file 829/2048: design29_n29.pdb
# Processing file 830/2048: design3_n44.pdb
# Processing file 831/2048: design9_n63.pdb
# Processing file 832/2048: design5_n47.pdb
# Processing file 833/2048: design2_n28.pdb
# Processing file 834/2048: design15_n42.pdb
# Processing file 835/2048: design17_n17.pdb
# Processing file 836/2048: design10_n56.pdb
# Processing file 837/2048: design22_n59.pdb
# Processing file 838/2048: design7_n0.pdb
# Processing file 839/2048: design19_n20.pdb
# Processing file 840/2048: design30_n42.pdb
# Processing file 841/2048: design29_n63.pdb
# Processing file 842/2048: design17_n47.pdb
# Processing file 843/2048: design28_n1.pdb
# Processing file 844/2048: design3_n42.pdb
# Processing file 845/2048: design20_n25.pdb
# Processing file 846/2048: design31_n5.pdb
# Processing file 847/2048: design12_n28.pdb
# Processing file 848/2048: design28_n33.pdb
# Processing file 849/2048: design22_n29.pdb
# Processing file 850/2048: design18_n62.pdb
# Processing file 851/2048: design10_n23.pdb
# Processing file 852/2048: design17_n58.pdb
# Processing file 853/2048: design25_n61.pdb
# Processing file 854/2048: design18_n13.pdb
# Processing file 855/2048: design1_n60.pdb
# Processing file 856/2048: design6_n36.pdb
# Processing file 857/2048: design0_n4.pdb
# Processing file 858/2048: design16_n1.pdb
# Processing file 859/2048: design4_n62.pdb
# Processing file 860/2048: design29_n48.pdb
# Processing file 861/2048: design14_n0.pdb
# Processing file 862/2048: design15_n33.pdb
# Processing file 863/2048: design29_n22.pdb
# Processing file 864/2048: design6_n28.pdb
# Processing file 865/2048: design13_n14.pdb
# Processing file 866/2048: design15_n24.pdb
# Processing file 867/2048: design13_n39.pdb
# Processing file 868/2048: design20_n29.pdb
# Processing file 869/2048: design7_n63.pdb
# Processing file 870/2048: design19_n0.pdb
# Processing file 871/2048: design24_n21.pdb
# Processing file 872/2048: design19_n9.pdb
# Processing file 873/2048: design27_n13.pdb
# Processing file 874/2048: design2_n45.pdb
# Processing file 875/2048: design28_n45.pdb
# Processing file 876/2048: design26_n3.pdb
# Processing file 877/2048: design16_n60.pdb
# Processing file 878/2048: design20_n35.pdb
# Processing file 879/2048: design0_n26.pdb
# Processing file 880/2048: design20_n39.pdb
# Processing file 881/2048: design25_n3.pdb
# Processing file 882/2048: design6_n8.pdb
# Processing file 883/2048: design0_n15.pdb
# Processing file 884/2048: design24_n18.pdb
# Processing file 885/2048: design7_n42.pdb
# Processing file 886/2048: design7_n29.pdb
# Processing file 887/2048: design4_n57.pdb
# Processing file 888/2048: design17_n9.pdb
# Processing file 889/2048: design9_n50.pdb
# Processing file 890/2048: design26_n21.pdb
# Processing file 891/2048: design25_n23.pdb
# Processing file 892/2048: design16_n38.pdb
# Processing file 893/2048: design18_n43.pdb
# Processing file 894/2048: design29_n21.pdb
# Processing file 895/2048: design9_n14.pdb
# Processing file 896/2048: design23_n13.pdb
# Processing file 897/2048: design7_n31.pdb
# Processing file 898/2048: design5_n62.pdb
# Processing file 899/2048: design31_n12.pdb
# Processing file 900/2048: design16_n11.pdb
# Processing file 901/2048: design26_n59.pdb
# Processing file 902/2048: design10_n59.pdb
# Processing file 903/2048: design5_n30.pdb
# Processing file 904/2048: design30_n21.pdb
# Processing file 905/2048: design29_n52.pdb
# Processing file 906/2048: design28_n29.pdb
# Processing file 907/2048: design30_n60.pdb
# Processing file 908/2048: design16_n9.pdb
# Processing file 909/2048: design5_n51.pdb
# Processing file 910/2048: design1_n61.pdb
# Processing file 911/2048: design30_n39.pdb
# Processing file 912/2048: design13_n11.pdb
# Processing file 913/2048: design23_n7.pdb
# Processing file 914/2048: design19_n14.pdb
# Processing file 915/2048: design0_n8.pdb
# Processing file 916/2048: design29_n41.pdb
# Processing file 917/2048: design25_n25.pdb
# Processing file 918/2048: design29_n14.pdb
# Processing file 919/2048: design3_n62.pdb
# Processing file 920/2048: design17_n35.pdb
# Processing file 921/2048: design31_n39.pdb
# Processing file 922/2048: design8_n9.pdb
# Processing file 923/2048: design27_n63.pdb
# Processing file 924/2048: design8_n5.pdb
# Processing file 925/2048: design12_n3.pdb
# Processing file 926/2048: design29_n42.pdb
# Processing file 927/2048: design17_n10.pdb
# Processing file 928/2048: design22_n25.pdb
# Processing file 929/2048: design14_n43.pdb
# Processing file 930/2048: design23_n9.pdb
# Processing file 931/2048: design4_n45.pdb
# Processing file 932/2048: design23_n4.pdb
# Processing file 933/2048: design3_n3.pdb
# Processing file 934/2048: design22_n58.pdb
# Processing file 935/2048: design15_n18.pdb
# Processing file 936/2048: design24_n41.pdb
# Processing file 937/2048: design4_n38.pdb
# Processing file 938/2048: design29_n59.pdb
# Processing file 939/2048: design2_n4.pdb
# Processing file 940/2048: design11_n2.pdb
# Processing file 941/2048: design10_n15.pdb
# Processing file 942/2048: design8_n27.pdb
# Processing file 943/2048: design3_n32.pdb
# Processing file 944/2048: design3_n29.pdb
# Processing file 945/2048: design25_n22.pdb
# Processing file 946/2048: design2_n59.pdb
# Processing file 947/2048: design30_n25.pdb
# Processing file 948/2048: design29_n36.pdb
# Processing file 949/2048: design26_n14.pdb
# Processing file 950/2048: design8_n58.pdb
# Processing file 951/2048: design16_n7.pdb
# Processing file 952/2048: design16_n55.pdb
# Processing file 953/2048: design24_n17.pdb
# Processing file 954/2048: design24_n58.pdb
# Processing file 955/2048: design29_n10.pdb
# Processing file 956/2048: design27_n11.pdb
# Processing file 957/2048: design26_n56.pdb
# Processing file 958/2048: design7_n7.pdb
# Processing file 959/2048: design14_n12.pdb
# Processing file 960/2048: design21_n52.pdb
# Processing file 961/2048: design27_n60.pdb
# Processing file 962/2048: design10_n48.pdb
# Processing file 963/2048: design25_n20.pdb
# Processing file 964/2048: design1_n7.pdb
# Processing file 965/2048: design11_n61.pdb
# Processing file 966/2048: design26_n37.pdb
# Processing file 967/2048: design22_n34.pdb
# Processing file 968/2048: design4_n60.pdb
# Processing file 969/2048: design18_n36.pdb
# Processing file 970/2048: design31_n19.pdb
# Processing file 971/2048: design3_n49.pdb
# Processing file 972/2048: design4_n26.pdb
# Processing file 973/2048: design5_n43.pdb
# Processing file 974/2048: design20_n58.pdb
# Processing file 975/2048: design3_n39.pdb
# Processing file 976/2048: design15_n41.pdb
# Processing file 977/2048: design14_n56.pdb
# Processing file 978/2048: design11_n11.pdb
# Processing file 979/2048: design15_n7.pdb
# Processing file 980/2048: design31_n31.pdb
# Processing file 981/2048: design11_n32.pdb
# Processing file 982/2048: design14_n44.pdb
# Processing file 983/2048: design31_n42.pdb
# Processing file 984/2048: design18_n8.pdb
# Processing file 985/2048: design28_n63.pdb
# Processing file 986/2048: design30_n58.pdb
# Processing file 987/2048: design15_n61.pdb
# Processing file 988/2048: design11_n58.pdb
# Processing file 989/2048: design21_n57.pdb
# Processing file 990/2048: design6_n50.pdb
# Processing file 991/2048: design31_n50.pdb
# Processing file 992/2048: design6_n21.pdb
# Processing file 993/2048: design6_n48.pdb
# Processing file 994/2048: design8_n37.pdb
# Processing file 995/2048: design13_n60.pdb
# Processing file 996/2048: design0_n17.pdb
# Processing file 997/2048: design23_n42.pdb
# Processing file 998/2048: design5_n52.pdb
# Processing file 999/2048: design3_n55.pdb
# Processing file 1000/2048: design14_n54.pdb
# Processing file 1001/2048: design16_n26.pdb
# Processing file 1002/2048: design21_n55.pdb
# Processing file 1003/2048: design11_n42.pdb
# Processing file 1004/2048: design4_n1.pdb
# Processing file 1005/2048: design26_n25.pdb
# Processing file 1006/2048: design29_n47.pdb
# Processing file 1007/2048: design11_n53.pdb
# Processing file 1008/2048: design27_n19.pdb
# Processing file 1009/2048: design27_n23.pdb
# Processing file 1010/2048: design11_n44.pdb
# Processing file 1011/2048: design23_n27.pdb
# Processing file 1012/2048: design7_n49.pdb
# Processing file 1013/2048: design12_n0.pdb
# Processing file 1014/2048: design15_n11.pdb
# Processing file 1015/2048: design27_n27.pdb
# Processing file 1016/2048: design5_n1.pdb
# Processing file 1017/2048: design28_n22.pdb
# Processing file 1018/2048: design24_n11.pdb
# Processing file 1019/2048: design14_n37.pdb
# Processing file 1020/2048: design14_n6.pdb
# Processing file 1021/2048: design9_n10.pdb
# Processing file 1022/2048: design17_n52.pdb
# Processing file 1023/2048: design21_n62.pdb
# Processing file 1024/2048: design19_n27.pdb
# Processing file 1025/2048: design20_n60.pdb
# Processing file 1026/2048: design19_n4.pdb
# Processing file 1027/2048: design4_n33.pdb
# Processing file 1028/2048: design1_n42.pdb
# Processing file 1029/2048: design5_n2.pdb
# Processing file 1030/2048: design25_n19.pdb
# Processing file 1031/2048: design24_n36.pdb
# Processing file 1032/2048: design0_n30.pdb
# Processing file 1033/2048: design18_n35.pdb
# Processing file 1034/2048: design4_n63.pdb
# Processing file 1035/2048: design13_n57.pdb
# Processing file 1036/2048: design17_n62.pdb
# Processing file 1037/2048: design7_n43.pdb
# Processing file 1038/2048: design30_n63.pdb
# Processing file 1039/2048: design10_n62.pdb
# Processing file 1040/2048: design3_n38.pdb
# Processing file 1041/2048: design7_n2.pdb
# Processing file 1042/2048: design19_n16.pdb
# Processing file 1043/2048: design9_n0.pdb
# Processing file 1044/2048: design12_n42.pdb
# Processing file 1045/2048: design16_n19.pdb
# Processing file 1046/2048: design0_n13.pdb
# Processing file 1047/2048: design30_n27.pdb
# Processing file 1048/2048: design19_n46.pdb
# Processing file 1049/2048: design31_n20.pdb
# Processing file 1050/2048: design15_n58.pdb
# Processing file 1051/2048: design3_n12.pdb
# Processing file 1052/2048: design14_n52.pdb
# Processing file 1053/2048: design7_n5.pdb
# Processing file 1054/2048: design3_n10.pdb
# Processing file 1055/2048: design18_n27.pdb
# Processing file 1056/2048: design4_n44.pdb
# Processing file 1057/2048: design0_n3.pdb
# Processing file 1058/2048: design18_n5.pdb
# Processing file 1059/2048: design23_n39.pdb
# Processing file 1060/2048: design13_n2.pdb
# Processing file 1061/2048: design2_n14.pdb
# Processing file 1062/2048: design3_n7.pdb
# Processing file 1063/2048: design0_n14.pdb
# Processing file 1064/2048: design12_n9.pdb
# Processing file 1065/2048: design23_n15.pdb
# Processing file 1066/2048: design27_n45.pdb
# Processing file 1067/2048: design29_n60.pdb
# Processing file 1068/2048: design18_n49.pdb
# Processing file 1069/2048: design24_n6.pdb
# Processing file 1070/2048: design30_n31.pdb
# Processing file 1071/2048: design23_n59.pdb
# Processing file 1072/2048: design26_n38.pdb
# Processing file 1073/2048: design10_n51.pdb
# Processing file 1074/2048: design4_n23.pdb
# Processing file 1075/2048: design16_n40.pdb
# Processing file 1076/2048: design28_n9.pdb
# Processing file 1077/2048: design3_n47.pdb
# Processing file 1078/2048: design19_n30.pdb
# Processing file 1079/2048: design15_n53.pdb
# Processing file 1080/2048: design8_n38.pdb
# Processing file 1081/2048: design27_n48.pdb
# Processing file 1082/2048: design25_n35.pdb
# Processing file 1083/2048: design1_n56.pdb
# Processing file 1084/2048: design14_n48.pdb
# Processing file 1085/2048: design19_n44.pdb
# Processing file 1086/2048: design21_n9.pdb
# Processing file 1087/2048: design27_n43.pdb
# Processing file 1088/2048: design14_n17.pdb
# Processing file 1089/2048: design27_n36.pdb
# Processing file 1090/2048: design6_n6.pdb
# Processing file 1091/2048: design4_n7.pdb
# Processing file 1092/2048: design4_n34.pdb
# Processing file 1093/2048: design20_n51.pdb
# Processing file 1094/2048: design25_n15.pdb
# Processing file 1095/2048: design0_n56.pdb
# Processing file 1096/2048: design8_n45.pdb
# Processing file 1097/2048: design21_n8.pdb
# Processing file 1098/2048: design25_n17.pdb
# Processing file 1099/2048: design17_n27.pdb
# Processing file 1100/2048: design31_n11.pdb
# Processing file 1101/2048: design17_n18.pdb
# Processing file 1102/2048: design3_n57.pdb
# Processing file 1103/2048: design21_n51.pdb
# Processing file 1104/2048: design28_n49.pdb
# Processing file 1105/2048: design11_n25.pdb
# Processing file 1106/2048: design18_n41.pdb
# Processing file 1107/2048: design5_n8.pdb
# Processing file 1108/2048: design22_n14.pdb
# Processing file 1109/2048: design5_n34.pdb
# Processing file 1110/2048: design1_n38.pdb
# ...
# Processing file 1697/2048: design19_n19.pdb
# Processing file 1698/2048: design2_n54.pdb
# Processing file 1699/2048: design8_n6.pdb
# Processing file 1700/2048: design0_n55.pdb
# Processing file 1701/2048: design2_n32.pdb
# Processing file 1702/2048: design26_n43.pdb
# Processing file 1703/2048: design14_n20.pdb
# Processing file 1704/2048: design30_n33.pdb
# Processing file 1705/2048: design17_n19.pdb
# Processing file 1706/2048: design13_n31.pdb
# Processing file 1707/2048: design8_n51.pdb
# Processing file 1708/2048: design8_n48.pdb
# Processing file 1709/2048: design3_n56.pdb
# Processing file 1710/2048: design30_n30.pdb
# Processing file 1711/2048: design12_n37.pdb
# Processing file 1712/2048: design16_n42.pdb
# Processing file 1713/2048: design6_n18.pdb
# Processing file 1714/2048: design22_n18.pdb
# Processing file 1715/2048: design29_n56.pdb
# Processing file 1716/2048: design6_n12.pdb
# Processing file 1717/2048: design23_n19.pdb
# Processing file 1718/2048: design25_n24.pdb
# Processing file 1719/2048: design24_n39.pdb
# Processing file 1720/2048: design29_n38.pdb
# Processing file 1721/2048: design29_n16.pdb
# Processing file 1722/2048: design18_n30.pdb
# Processing file 1723/2048: design2_n46.pdb
# Processing file 1724/2048: design22_n43.pdb
# Processing file 1725/2048: design23_n32.pdb
# Processing file 1726/2048: design17_n48.pdb
# Processing file 1727/2048: design4_n6.pdb
# Processing file 1728/2048: design29_n27.pdb
# Processing file 1729/2048: design4_n58.pdb
# Processing file 1730/2048: design18_n15.pdb
# Processing file 1731/2048: design4_n10.pdb
# Processing file 1732/2048: design30_n49.pdb
# Processing file 1733/2048: design13_n40.pdb
# Processing file 1734/2048: design0_n49.pdb
# Processing file 1735/2048: design23_n6.pdb
# Processing file 1736/2048: design21_n17.pdb
# Processing file 1737/2048: design21_n61.pdb
# Processing file 1738/2048: design11_n49.pdb
# Processing file 1739/2048: design22_n19.pdb
# Processing file 1740/2048: design22_n5.pdb
# Processing file 1741/2048: design20_n10.pdb
# Processing file 1742/2048: design18_n61.pdb
# Processing file 1743/2048: design28_n32.pdb
# Processing file 1744/2048: design31_n37.pdb
# Processing file 1745/2048: design20_n61.pdb
# Processing file 1746/2048: design20_n1.pdb
# Processing file 1747/2048: design24_n8.pdb
# Processing file 1748/2048: design21_n33.pdb
# Processing file 1749/2048: design30_n13.pdb
# Processing file 1750/2048: design20_n49.pdb
# Processing file 1751/2048: design15_n1.pdb
# Processing file 1752/2048: design7_n9.pdb
# Processing file 1753/2048: design31_n0.pdb
# Processing file 1754/2048: design17_n42.pdb
# Processing file 1755/2048: design17_n45.pdb
# Processing file 1756/2048: design3_n18.pdb
# Processing file 1757/2048: design24_n34.pdb
# Processing file 1758/2048: design31_n59.pdb
# Processing file 1759/2048: design8_n11.pdb
# Processing file 1760/2048: design22_n36.pdb
# Processing file 1761/2048: design27_n42.pdb
# Processing file 1762/2048: design23_n10.pdb
# Processing file 1763/2048: design6_n56.pdb
# Processing file 1764/2048: design9_n44.pdb
# Processing file 1765/2048: design25_n38.pdb
# Processing file 1766/2048: design15_n13.pdb
# Processing file 1767/2048: design21_n32.pdb
# Processing file 1768/2048: design9_n32.pdb
# Processing file 1769/2048: design25_n52.pdb
# Processing file 1770/2048: design19_n7.pdb
# Processing file 1771/2048: design12_n11.pdb
# Processing file 1772/2048: design4_n61.pdb
# Processing file 1773/2048: design17_n25.pdb
# Processing file 1774/2048: design15_n15.pdb
# Processing file 1775/2048: design26_n22.pdb
# Processing file 1776/2048: design18_n1.pdb
# Processing file 1777/2048: design12_n59.pdb
# Processing file 1778/2048: design5_n18.pdb
# Processing file 1779/2048: design23_n0.pdb
# Processing file 1780/2048: design29_n46.pdb
# Processing file 1781/2048: design0_n25.pdb
# Processing file 1782/2048: design2_n51.pdb
# Processing file 1783/2048: design6_n32.pdb
# Processing file 1784/2048: design5_n13.pdb
# Processing file 1785/2048: design22_n23.pdb
# Processing file 1786/2048: design5_n29.pdb
# Processing file 1787/2048: design19_n28.pdb
# Processing file 1788/2048: design16_n37.pdb
# Processing file 1789/2048: design9_n39.pdb
# Processing file 1790/2048: design5_n21.pdb
# Processing file 1791/2048: design12_n16.pdb
# Processing file 1792/2048: design15_n16.pdb
# Processing file 1793/2048: design12_n49.pdb
# Processing file 1794/2048: design3_n40.pdb
# Processing file 1795/2048: design31_n53.pdb
# Processing file 1796/2048: design15_n63.pdb
# Processing file 1797/2048: design4_n27.pdb
# Processing file 1798/2048: design5_n54.pdb
# Processing file 1799/2048: design18_n38.pdb
# Processing file 1800/2048: design9_n43.pdb
# Processing file 1801/2048: design25_n56.pdb
# Processing file 1802/2048: design30_n40.pdb
# Processing file 1803/2048: design8_n13.pdb
# Processing file 1804/2048: design22_n52.pdb
# Processing file 1805/2048: design2_n33.pdb
# Processing file 1806/2048: design3_n23.pdb
# Processing file 1807/2048: design16_n53.pdb
# Processing file 1808/2048: design2_n44.pdb
# Processing file 1809/2048: design22_n60.pdb
# Processing file 1810/2048: design13_n9.pdb
# Processing file 1811/2048: design14_n21.pdb
# Processing file 1812/2048: design3_n9.pdb
# Processing file 1813/2048: design30_n57.pdb
# Processing file 1814/2048: design31_n41.pdb
# Processing file 1815/2048: design30_n55.pdb
# Processing file 1816/2048: design28_n25.pdb
# Processing file 1817/2048: design22_n38.pdb
# Processing file 1818/2048: design15_n45.pdb
# Processing file 1819/2048: design6_n38.pdb
# Processing file 1820/2048: design3_n61.pdb
# Processing file 1821/2048: design23_n26.pdb
# Processing file 1822/2048: design13_n51.pdb
# Processing file 1823/2048: design29_n49.pdb
# Processing file 1824/2048: design8_n28.pdb
# Processing file 1825/2048: design22_n63.pdb
# Processing file 1826/2048: design7_n33.pdb
# Processing file 1827/2048: design10_n46.pdb
# Processing file 1828/2048: design14_n35.pdb
# Processing file 1829/2048: design5_n36.pdb
# Processing file 1830/2048: design10_n28.pdb
# Processing file 1831/2048: design25_n26.pdb
# Processing file 1832/2048: design0_n59.pdb
# Processing file 1833/2048: design10_n30.pdb
# Processing file 1834/2048: design16_n10.pdb
# Processing file 1835/2048: design31_n25.pdb
# Processing file 1836/2048: design17_n41.pdb
# Processing file 1837/2048: design26_n18.pdb
# Processing file 1838/2048: design4_n51.pdb
# Processing file 1839/2048: design2_n20.pdb
# Processing file 1840/2048: design30_n12.pdb
# Processing file 1841/2048: design10_n8.pdb
# Processing file 1842/2048: design7_n57.pdb
# Processing file 1843/2048: design19_n11.pdb
# Processing file 1844/2048: design31_n40.pdb
# Processing file 1845/2048: design9_n17.pdb
# Processing file 1846/2048: design18_n24.pdb
# Processing file 1847/2048: design19_n56.pdb
# Processing file 1848/2048: design8_n20.pdb
# Processing file 1849/2048: design6_n45.pdb
# Processing file 1850/2048: design11_n27.pdb
# Processing file 1851/2048: design4_n24.pdb
# Processing file 1852/2048: design27_n30.pdb
# Processing file 1853/2048: design24_n44.pdb
# Processing file 1854/2048: design27_n9.pdb
# Processing file 1855/2048: design20_n7.pdb
# Processing file 1856/2048: design28_n4.pdb
# Processing file 1857/2048: design19_n18.pdb
# Processing file 1858/2048: design24_n28.pdb
# Processing file 1859/2048: design0_n39.pdb
# Processing file 1860/2048: design4_n46.pdb
# Processing file 1861/2048: design25_n63.pdb
# Processing file 1862/2048: design29_n3.pdb
# Processing file 1863/2048: design27_n16.pdb
# Processing file 1864/2048: design24_n59.pdb
# Processing file 1865/2048: design20_n42.pdb
# Processing file 1866/2048: design30_n9.pdb
# Processing file 1867/2048: design15_n0.pdb
# Processing file 1868/2048: design18_n44.pdb
# Processing file 1869/2048: design28_n28.pdb
# Processing file 1870/2048: design26_n10.pdb
# Processing file 1871/2048: design20_n53.pdb
# Processing file 1872/2048: design15_n19.pdb
# Processing file 1873/2048: design15_n60.pdb
# Processing file 1874/2048: design30_n56.pdb
# Processing file 1875/2048: design2_n0.pdb
# Processing file 1876/2048: design20_n9.pdb
# Processing file 1877/2048: design13_n26.pdb
# Processing file 1878/2048: design12_n63.pdb
# Processing file 1879/2048: design14_n50.pdb
# Processing file 1880/2048: design17_n23.pdb
# Processing file 1881/2048: design3_n36.pdb
# Processing file 1882/2048: design24_n7.pdb
# Processing file 1883/2048: design28_n7.pdb
# Processing file 1884/2048: design21_n36.pdb
# Processing file 1885/2048: design18_n10.pdb
# Processing file 1886/2048: design1_n47.pdb
# Processing file 1887/2048: design29_n24.pdb
# Processing file 1888/2048: design21_n23.pdb
# Processing file 1889/2048: design7_n4.pdb
# Processing file 1890/2048: design1_n59.pdb
# Processing file 1891/2048: design27_n29.pdb
# Processing file 1892/2048: design8_n54.pdb
# Processing file 1893/2048: design25_n48.pdb
# Processing file 1894/2048: design12_n50.pdb
# Processing file 1895/2048: design12_n35.pdb
# Processing file 1896/2048: design8_n52.pdb
# Processing file 1897/2048: design8_n55.pdb
# Processing file 1898/2048: design7_n8.pdb
# Processing file 1899/2048: design16_n56.pdb
# Processing file 1900/2048: design17_n28.pdb
# Processing file 1901/2048: design20_n46.pdb
# Processing file 1902/2048: design29_n28.pdb
# Processing file 1903/2048: design10_n26.pdb
# Processing file 1904/2048: design10_n7.pdb
# Processing file 1905/2048: design31_n24.pdb
# Processing file 1906/2048: design6_n0.pdb
# Processing file 1907/2048: design23_n28.pdb
# Processing file 1908/2048: design19_n21.pdb
# Processing file 1909/2048: design25_n37.pdb
# Processing file 1910/2048: design31_n55.pdb
# Processing file 1911/2048: design2_n22.pdb
# Processing file 1912/2048: design23_n52.pdb
# Processing file 1913/2048: design21_n37.pdb
# Processing file 1914/2048: design16_n50.pdb
# Processing file 1915/2048: design2_n24.pdb
# Processing file 1916/2048: design28_n6.pdb
# Processing file 1917/2048: design15_n4.pdb
# Processing file 1918/2048: design29_n54.pdb
# Processing file 1919/2048: design21_n16.pdb
# Processing file 1920/2048: design16_n27.pdb
# Processing file 1921/2048: design21_n31.pdb
# Processing file 1922/2048: design30_n62.pdb
# Processing file 1923/2048: design2_n29.pdb
# Processing file 1924/2048: design21_n14.pdb
# Processing file 1925/2048: design29_n13.pdb
# Processing file 1926/2048: design13_n5.pdb
# Processing file 1927/2048: design26_n41.pdb
# Processing file 1928/2048: design28_n23.pdb
# Processing file 1929/2048: design27_n58.pdb
# Processing file 1930/2048: design10_n27.pdb
# Processing file 1931/2048: design13_n49.pdb
# Processing file 1932/2048: design19_n43.pdb
# Processing file 1933/2048: design17_n38.pdb
# Processing file 1934/2048: design24_n61.pdb
# Processing file 1935/2048: design1_n19.pdb
# Processing file 1936/2048: design26_n28.pdb
# Processing file 1937/2048: design22_n41.pdb
# Processing file 1938/2048: design11_n21.pdb
# Processing file 1939/2048: design19_n24.pdb
# Processing file 1940/2048: design14_n19.pdb
# Processing file 1941/2048: design21_n39.pdb
# Processing file 1942/2048: design27_n37.pdb
# Processing file 1943/2048: design18_n4.pdb
# Processing file 1944/2048: design6_n3.pdb
# Processing file 1945/2048: design19_n31.pdb
# Processing file 1946/2048: design9_n54.pdb
# Processing file 1947/2048: design13_n13.pdb
# Processing file 1948/2048: design3_n46.pdb
# Processing file 1949/2048: design31_n22.pdb
# Processing file 1950/2048: design15_n43.pdb
# Processing file 1951/2048: design12_n19.pdb
# Processing file 1952/2048: design22_n53.pdb
# Processing file 1953/2048: design11_n30.pdb
# Processing file 1954/2048: design6_n59.pdb
# Processing file 1955/2048: design29_n37.pdb
# Processing file 1956/2048: design11_n8.pdb
# Processing file 1957/2048: design27_n50.pdb
# Processing file 1958/2048: design8_n47.pdb
# Processing file 1959/2048: design14_n23.pdb
# Processing file 1960/2048: design27_n3.pdb
# Processing file 1961/2048: design10_n54.pdb
# Processing file 1962/2048: design13_n19.pdb
# Processing file 1963/2048: design1_n30.pdb
# Processing file 1964/2048: design22_n31.pdb
# Processing file 1965/2048: design17_n39.pdb
# Processing file 1966/2048: design28_n20.pdb
# Processing file 1967/2048: design14_n2.pdb
# Processing file 1968/2048: design7_n1.pdb
# Processing file 1969/2048: design0_n20.pdb
# Processing file 1970/2048: design17_n40.pdb
# Processing file 1971/2048: design11_n14.pdb
# Processing file 1972/2048: design31_n16.pdb
# Processing file 1973/2048: design28_n62.pdb
# Processing file 1974/2048: design2_n56.pdb
# Processing file 1975/2048: design27_n61.pdb
# Processing file 1976/2048: design14_n39.pdb
# Processing file 1977/2048: design14_n47.pdb
# Processing file 1978/2048: design4_n25.pdb
# Processing file 1979/2048: design24_n22.pdb
# Processing file 1980/2048: design24_n57.pdb
# Processing file 1981/2048: design18_n32.pdb
# Processing file 1982/2048: design1_n9.pdb
# Processing file 1983/2048: design7_n58.pdb
# Processing file 1984/2048: design28_n58.pdb
# Processing file 1985/2048: design19_n47.pdb
# Processing file 1986/2048: design10_n29.pdb
# Processing file 1987/2048: design1_n51.pdb
# Processing file 1988/2048: design18_n34.pdb
# Processing file 1989/2048: design23_n56.pdb
# Processing file 1990/2048: design25_n62.pdb
# Processing file 1991/2048: design29_n44.pdb
# Processing file 1992/2048: design21_n44.pdb
# Processing file 1993/2048: design14_n16.pdb
# Processing file 1994/2048: design14_n4.pdb
# Processing file 1995/2048: design6_n35.pdb
# Processing file 1996/2048: design26_n17.pdb
# Processing file 1997/2048: design24_n35.pdb
# Processing file 1998/2048: design21_n7.pdb
# Processing file 1999/2048: design9_n58.pdb
# Processing file 2000/2048: design8_n40.pdb
# Processing file 2001/2048: design16_n17.pdb
# Processing file 2002/2048: design31_n28.pdb
# Processing file 2003/2048: design24_n29.pdb
# Processing file 2004/2048: design12_n56.pdb
# Processing file 2005/2048: design1_n15.pdb
# Processing file 2006/2048: design3_n28.pdb
# Processing file 2007/2048: design26_n55.pdb
# Processing file 2008/2048: design0_n58.pdb
# Processing file 2009/2048: design27_n54.pdb
# Processing file 2010/2048: design11_n54.pdb
# Processing file 2011/2048: design20_n52.pdb
# Processing file 2012/2048: design19_n6.pdb
# Processing file 2013/2048: design19_n10.pdb
# Processing file 2014/2048: design2_n58.pdb
# Processing file 2015/2048: design24_n42.pdb
# Processing file 2016/2048: design16_n13.pdb
# Processing file 2017/2048: design9_n41.pdb
# Processing file 2018/2048: design2_n37.pdb
# Processing file 2019/2048: design22_n8.pdb
# Processing file 2020/2048: design12_n58.pdb
# Processing file 2021/2048: design1_n41.pdb
# Processing file 2022/2048: design9_n4.pdb
# Processing file 2023/2048: design31_n18.pdb
# Processing file 2024/2048: design22_n39.pdb
# Processing file 2025/2048: design7_n17.pdb
# Processing file 2026/2048: design14_n32.pdb
# Processing file 2027/2048: design20_n36.pdb
# Processing file 2028/2048: design10_n21.pdb
# Processing file 2029/2048: design31_n21.pdb
# Processing file 2030/2048: design4_n48.pdb
# Processing file 2031/2048: design26_n45.pdb
# Processing file 2032/2048: design19_n1.pdb
# Processing file 2033/2048: design12_n2.pdb
# Processing file 2034/2048: design14_n26.pdb
# Processing file 2035/2048: design6_n61.pdb
# Processing file 2036/2048: design5_n53.pdb
# Processing file 2037/2048: design3_n45.pdb
# Processing file 2038/2048: design23_n14.pdb
# Processing file 2039/2048: design15_n50.pdb
# Processing file 2040/2048: design22_n45.pdb
# Processing file 2041/2048: design3_n11.pdb
# Processing file 2042/2048: design9_n61.pdb
# Processing file 2043/2048: design11_n15.pdb
# Processing file 2044/2048: design26_n1.pdb
# Processing file 2045/2048: design19_n13.pdb
# Processing file 2046/2048: design4_n56.pdb
# Processing file 2047/2048: design7_n40.pdb
# Processing file 2048/2048: design26_n16.pdb
# Saved structure analysis to /content/drive/MyDrive/PDB-files/202501xx/3NOB-70-110-all_pdb/3NOB-70-110-all_pdb_250131_structure.csv
# Merging with AF2 scores from /content/drive/MyDrive/PDB-files/202501xx/3NOB-70-110-all_pdb/af2_scores.csv
# Saved combined results to /content/drive/MyDrive/PDB-files/202501xx/3NOB-70-110-all_pdb/3NOB-70-110-all_pdb_250131_combined.csv
# Saved PowerPoint to /content/drive/MyDrive/PDB-files/202501xx/3NOB-70-110-all_pdb/3NOB-70-110-all_pdb_250131_analysis.pptx
# Saved combined FASTA file to /content/drive/MyDrive/PDB-files/202501xx/3NOB-70-110-all_pdb/3NOB-70-110-all_pdb_250131_sequences.fasta
#
# Analysis completed successfully!
